# %% [markdown]
# # Limpieza de dtos de Macrofauna

# %%
import numpy as np 
import pandas as pd
import re 
import datetime
import traceback as tb
import sys

df_macrofauna = pd.read_excel(r'C:\Users\felipe.abarzua\Desktop\DATA_AMBIENTALES\Proyecto Seguimiento Ambiental\2019_P656115\2_BD_MACROFAUNA_2019.xlsx' , sheet_name= 'BD_Macrofauna2019')

# %%
df_macrofauna
# Out:
#                                    Nombre del Proyecto:  \
# 0                                  Codigo del Proyecto:
# 1                                       Etapa Proyecto:
# 2                                         Jefe Proyecto
# 3                                         Institucion:
# 4                                       Nombre Sector:
# ...                                                 ...
# 3206  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 3207  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 3208  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 3209  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 3210  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
#
#      ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO 2019 -2020  \
# 0                                               656-115
# 1     Objetivo 1. Actividad 2. Muestreos y Analisis ...
# 2                                          Gastón Vidal
# 3                         INSTITUTO DE FOMENTO PESQUERO
# 4     Atacama (Caldera-Bahia Inglesa), Coquimbo (Ton...
# ...                                                 ...
# 3206                                            656-115
# 3207                                            656-115
# 3208                                            656-115
# 3209                                            656-115
# 3210                                            656-115
#
#                                              Unnamed: 2    Unnamed: 3  \
# 0                                                   NaN           NaN
# 1                                                   NaN           NaN
# 2                                                   NaN           NaN
# 3                                                   NaN           NaN
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 3206  Objetivo 1. Actividad 2. Muestreos y Analisis ...  GASTON VIDAL
# 3207  Objetivo 1. Actividad 2. Muestreos y Analisis ...  GASTON VIDAL
# 3208  Objetivo 1. Actividad 2. Muestreos y Analisis ...  GASTON VIDAL
# 3209  Objetivo 1. Actividad 2. Muestreos y Analisis ...  GASTON VIDAL
# 3210  Objetivo 1. Actividad 2. Muestreos y Analisis ...  GASTON VIDAL
#
#                          Unnamed: 4 Unnamed: 5 Unnamed: 6  Unnamed: 7  \
# 0                               NaN        NaN        NaN         NaN
# 1                               NaN        NaN        NaN         NaN
# 2                               NaN        NaN        NaN         NaN
# 3                               NaN        NaN        NaN         NaN
# 4                               NaN        NaN        NaN         NaN
# ...                             ...        ...        ...         ...
# 3206  INSTITUTO DE FOMENTO PESQUERO    Natales        XII  Macrofauna
# 3207  INSTITUTO DE FOMENTO PESQUERO    Natales        XII  Macrofauna
# 3208  INSTITUTO DE FOMENTO PESQUERO    Natales        XII  Macrofauna
# 3209  INSTITUTO DE FOMENTO PESQUERO    Natales        XII  Macrofauna
# 3210  INSTITUTO DE FOMENTO PESQUERO    Natales        XII  Macrofauna
#
#                Unnamed: 8           Unnamed: 9  ... Unnamed: 17 Unnamed: 18  \
# 0                     NaN                  NaN  ...         NaN         NaN
# 1                     NaN                  NaN  ...         NaN         NaN
# 2                     NaN                  NaN  ...         NaN         NaN
# 3                     NaN                  NaN  ...         NaN         NaN
# 4                     NaN                  NaN  ...         NaN         NaN
# ...                   ...                  ...  ...         ...         ...
# 3206  2019-08-11 00:00:00  2019-08-11 00:00:00  ...          11      0.0004
# 3207  2019-08-11 00:00:00  2019-08-11 00:00:00  ...          29      0.0011
# 3208  2019-08-11 00:00:00  2019-08-11 00:00:00  ...           1      0.0002
# 3209  2019-08-11 00:00:00  2019-08-11 00:00:00  ...           5      0.0004
# 3210  2019-08-11 00:00:00  2019-08-11 00:00:00  ...           1      0.0061
#
#      Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22   Unnamed: 23  \
# 0            NaN         NaN         NaN         NaN           NaN
# 1            NaN         NaN         NaN         NaN           NaN
# 2            NaN         NaN         NaN         NaN           NaN
# 3            NaN         NaN         NaN         NaN           NaN
# 4            NaN         NaN         NaN         NaN           NaN
# ...          ...         ...         ...         ...           ...
# 3206         110       0.004    Annelida  Polychaeta  Dorvilleidae
# 3207         290       0.011  Arthropoda    Copepoda      Copepoda
# 3208          10       0.002  Arthropoda  Tanaidacea    Tanaidacea
# 3209          50       0.004    Annelida  Polychaeta  Cirratulidae
# 3210          10       0.061    Mollusca    Bivalvia    Malletidae
#
#                Unnamed: 24 Unnamed: 25 Unnamed: 26
# 0                      NaN         NaN         NaN
# 1                      NaN         NaN         NaN
# 2                      NaN         NaN         NaN
# 3                      NaN         NaN         NaN
# 4                      NaN         NaN         NaN
# ...                    ...         ...         ...
# 3206       Pettiboneia wui         NaN         NaN
# 3207           Ciclopoideo         NaN         NaN
# 3208            Tanaidacea         NaN         NaN
# 3209       Apelochaeta sp.         NaN         NaN
# 3210  Malletia magellanica         NaN         NaN
#
# [3211 rows x 27 columns]

# %%
def limpieza_macrofauna(df):

    try:

        #Eliminamos las fil as innecesarias
        df =  df.iloc[13: , :]

        #Reiniciamos los indices del dataframe y eliminamos la columna de index 
        df =  df.reset_index(drop = True)

        #Creamos una copia del dataframe
        df_macrofauna_copy = df.copy()

        #Dejamos la primera fila como columna
        df_macrofauna_copy.columns = df_macrofauna_copy.iloc[0]

        #Eliminamos la primera fila del dataset 
        df_macrofauna_copy = df_macrofauna_copy.iloc[1: , :]

        #Reiniciamos los indices del dataframe
        df_macrofauna_copy = df_macrofauna_copy.reset_index(drop =  True)

        #Agregamos la columna ID 
        df_macrofauna_copy.insert(0 , 'ID' , df_macrofauna_copy.index + 1)

        #Creamos la lista de columnas 
        columnas = df_macrofauna_copy.columns.to_list()

        #Creamos las columnas fijas y las columnas variables

        columnas_fijas = ['ID', 'NOMB_PROY', 'COD_PROY', 'ETAP_PROY', 'JEFE_PROY', 'INST_PROY', 'NOM_SECTOR', 'COD_REG', 'VARIABLE', 'FECHA_INI', 'FECHA_TER', 'N_ESTACION', 'LATITUD', 'LONGUITUD', 'PROF_SECT', 'N°_TAXA','NUM_EJEMPL']

        columnas_variables = ['NUM_EJEMPL', 'TIPO_DRAGA', 'ABUNDANCIA', 'BIOMASA', 'IND_M2', 'GRS_M2']

        #Realizamos un melt para convertir las columnas de variables a filas 

        df_macrofauna_copy = pd.melt(df_macrofauna_copy , id_vars= columnas_fijas , value_vars=columnas_variables , var_name= 'VARIABLES_MUESTREO' , value_name= 'VALOR')

        #Renombramos los nombres de VARIABLES_MUESTREO

        df_macrofauna_copy['VARIABLES_MUESTREO'] = np.where(df_macrofauna_copy['VARIABLES_MUESTREO'] == 'ABUNDANCIA' , 'ABUNDANCIA TOTAL' , df_macrofauna_copy['VARIABLES_MUESTREO'])
        df_macrofauna_copy['VARIABLES_MUESTREO'] = np.where(df_macrofauna_copy['VARIABLES_MUESTREO'] == 'BIOMASA' , 'BIOMASA TOTAL' , df_macrofauna_copy['VARIABLES_MUESTREO'])

        #Reemplazamos todos los valores de NOMB_PROY

        df_macrofauna_copy['NOMB_PROY'] = 'ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO 2019-2020'

        #Renombramos la columnas 

        df_macrofauna_copy = df_macrofauna_copy.rename(columns = {"LONGUITUD" : "LONGITUD"})

        



        return df_macrofauna_copy , columnas

    except Exception as e:
        print(f"Ocurrió un error en la función limpieza_ctd: {e}")
        ex = sys.exc_info()[2]
        print("Error en el archivo : " + str(ex.tb_frame) + " En la linea : " + str(ex.tb_lineno))
        
        return None #O devuelve un valor que indique el fallo

# %%
df_macrofauna_copy , columnas = limpieza_macrofauna(df_macrofauna)

# %%
df_macrofauna_copy.to_csv('output/2019/AMBIENTALES_MACROFAUNA_2019.csv' , index=False)

# %% [markdown]
# # Limpieza de datos de CTD y CTD COMPU

# %%
df_ctd = pd.read_excel(r'C:\Users\felipe.abarzua\Desktop\DATA_AMBIENTALES\Proyecto Seguimiento Ambiental\2019_P656115\3_BD_CTD_SEGUIMIENTO2019.xlsx' , sheet_name= 'Base de Datos CTD2019 IFOP')

df_ctd_compu = pd.read_excel(r'C:\Users\felipe.abarzua\Desktop\DATA_AMBIENTALES\Proyecto Seguimiento Ambiental\2019_P656115\6_BD_CTD_COMPU_2019.xlsx' , sheet_name='Sept_nov_COMPU')

# %%
df_ctd
# Out:
#                                    Nombre del Proyecto:  \
# 0                                  Codigo del Proyecto:
# 1                            Fecha inicio del muestreo:
# 2                               Fecha fin del muestreo:
# 3                                 Equipos de medición:
# 4                                                   NaN
# ...                                                 ...
# 6428  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 6429  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 6430  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 6431  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 6432  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
#
#      ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO 2019 -2020  \
# 0                                               656-115
# 1                                        9 mayo de 2019
# 2                                      26 de junio 2019
# 3     CTD SeaBird SBE19plus// SerialNumber 01907566/...
# 4                               Botella Niskin 5 litros
# ...                                                 ...
# 6428                                            656-115
# 6429                                            656-115
# 6430                                            656-115
# 6431                                            656-115
# 6432                                            656-115
#
#                Unnamed: 2           Unnamed: 3             Unnamed: 4  \
# 0                     NaN                  NaN                    NaN
# 1                     NaN                  NaN                    NaN
# 2                     NaN                  NaN                    NaN
# 3                     NaN                  NaN                    NaN
# 4                     NaN                  NaN                    NaN
# ...                   ...                  ...                    ...
# 6428  2019-06-20 00:00:00  2019-06-20 00:00:00  CTD SeaBird SBE19plus
# 6429  2019-06-20 00:00:00  2019-06-20 00:00:00  CTD SeaBird SBE19plus
# 6430  2019-06-20 00:00:00  2019-06-20 00:00:00  CTD SeaBird SBE19plus
# 6431  2019-06-20 00:00:00  2019-06-20 00:00:00  CTD SeaBird SBE19plus
# 6432  2019-06-20 00:00:00  2019-06-20 00:00:00  CTD SeaBird SBE19plus
#
#      Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 18  \
# 0           NaN        NaN        NaN        NaN        NaN  ...         NaN
# 1           NaN        NaN        NaN        NaN        NaN  ...         NaN
# 2           NaN        NaN        NaN        NaN        NaN  ...         NaN
# 3           NaN        NaN        NaN        NaN        NaN  ...         NaN
# 4           NaN        NaN        NaN        NaN        NaN  ...         NaN
# ...         ...        ...        ...        ...        ...  ...         ...
# 6428 -46.676652   -73.9255        127      135.9     6.1698  ...         NaN
# 6429 -46.676652   -73.9255        128      135.9     6.1781  ...         NaN
# 6430 -46.676652   -73.9255        129      135.9     6.1842  ...         NaN
# 6431 -46.676652   -73.9255        130      135.9     6.1917  ...         NaN
# 6432 -46.676652   -73.9255        131      135.9     6.1961  ...         NaN
#
#      Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 6428         NaN         NaN         NaN          XI          31         NaN
# 6429         NaN         NaN         NaN          XI          31         NaN
# 6430         NaN         NaN         NaN          XI          31         NaN
# 6431         NaN         NaN         NaN          XI          31         NaN
# 6432         NaN         NaN         NaN          XI          31         NaN
#
#      Unnamed: 25 Unnamed: 26 Unnamed: 27
# 0            NaN         NaN         NaN
# 1            NaN         NaN         NaN
# 2            NaN         NaN         NaN
# 3            NaN         NaN         NaN
# 4            NaN         NaN         NaN
# ...          ...         ...         ...
# 6428          31    14:56:00         NaN
# 6429          31    14:56:00         NaN
# 6430          31    14:56:00         NaN
# 6431          31    14:56:00         NaN
# 6432          31    14:56:00         NaN
#
# [6433 rows x 28 columns]

# %%
def limpieza_ctd(df):
    
    try:
        # Eliminamos las filas innecesarias
        df = df.iloc[18:, :]

        # Reiniciamos los indices
        df = df.reset_index(drop=True)

        # Creamos una copia del dataset
        df_ctd_copy = df.copy()

        # Dejamos la primera fila como columna
        df_ctd_copy.columns = df_ctd_copy.iloc[0]

        # Eliminamos la primera fila
        df_ctd_copy = df_ctd_copy.iloc[1:, :]

        # Reiniciamos los indices
        df_ctd_copy = df_ctd_copy.reset_index(drop=True)

        # Agregamos una columna de ID para identificar los datos antes de realizar el Melt
        df_ctd_copy.insert(0, 'ID', df_ctd_copy.index + 1)

        # Renombramos las columnas
        df_ctd_copy = df_ctd_copy.rename(columns={  'ESTACION' : 'N_ESTACION' ,  'LONGUITUD': 'LONGITUD', 'TEMPERATUR': 'TEMPERATURA', 'HORA_DATO  ': 'HORA_DATO', 'OXIG_ml/L': 'OXIGENO_DIS_ML/L', 'OXIG_mg/L': 'OXIGENO_DIS_MG/L', 'OXIG_%sat': 'OXIGENO_DIS_SAT', 'OX_umol/kg': 'OXIGENO_DIS_UMOLKG', 'FLUORESCEN': 'FLUORESCENCIA'})

        # Creamos las columnas fijas y columnas de variables
        columnas_fijas = ['ID', 'NOMB_PROY', 'COD_PROY', 'FECHA_INI', 'FECHA_TER', 'EQUIPO', 'LATITUD', 'LONGITUD', 'PROF_EQ', 'PROF_SECT', 'COD_REG', 'OBSERV', 'SHAPE', 'N_ESTACION', 'HORA_DATO']
        columnas_variables = ['TEMPERATURA', 'OXIGENO_DIS_ML/L', 'OXIGENO_DIS_MG/L', 'OXIGENO_DIS_SAT', 'OXIGENO_DIS_UMOLKG', 'FLUORESCENCIA', 'SALINIDAD', 'DENSIDAD', 'CLOROFILA', 'FEOPIGMEN', 'NITRATO', 'FOSFATO', 'SILICATO']

        """
        Realizamos un melt para convertir las columnas de Variables a filas

            Necesita:
            1. Dataframe a cambiar
            2. id_vars : Lista o Tupla de las columnas Fijas
            3. value_vars : Lista o Tupla de las columnas de Variables
            4. var_name : Nombre de la nueva columna de las Variables
            5. value_name : Nombre de la columna con los valores de la columna de Variables

        """

        df_ctd_copy = pd.melt(df_ctd_copy, id_vars=columnas_fijas, value_vars=columnas_variables, var_name='VARIABLE', value_name='VALOR')

        # Creamos una columna de fecha

        # df_ctd_copy.insert(10 , 'FECHA_DATO' , df_ctd_copy.apply(lambda row: datetime.datetime(row['FECHA_TER']), axis=1) )

        # Convertimos la HORA_DATO a string

        df_ctd_copy['HORA_DATO'] = df_ctd_copy['HORA_DATO'].astype(str)

        # Remplazamos los 'nan'

        df_ctd_copy['HORA_DATO'] = np.where(df_ctd_copy['HORA_DATO'] == 'nan', '00:00:00', df_ctd_copy['HORA_DATO'])

        # Creamos un campo de FECHA_DATO
        df_ctd_copy['FECHA_DATO'] = df_ctd_copy['FECHA_TER'].dt.strftime('%d/%m/%Y') + ' ' + df_ctd_copy['HORA_DATO']

        # Realizamos un formateo a los campos de fechas
        df_ctd_copy['FECHA_INI'] = pd.to_datetime(df_ctd_copy['FECHA_INI'], format='%d/%m/%Y %H:%M:%S', errors='coerce')
        df_ctd_copy['FECHA_TER'] = pd.to_datetime(df_ctd_copy['FECHA_TER'], format='%d/%m/%Y %H:%M:%S', errors='coerce')
        df_ctd_copy['FECHA_DATO'] = pd.to_datetime(df_ctd_copy['FECHA_DATO'], format='%d/%m/%Y %H:%M:%S', errors='coerce')

        #



    
        return df_ctd_copy, columnas_fijas, columnas_variables

    except Exception as e:
        print(f"Ocurrió un error en la función limpieza_ctd: {e}")
        ex = sys.exc_info()[2]
        print("Error en el archivo : " + str(ex.tb_frame) + " En la linea : " + str(ex.tb_lineno))
        
        return None, None, None  # O devuelve un valor que indique el fallo

# %%
df_ctd_copy , columnas_fijas , columnas_variables = limpieza_ctd(df_ctd)

# %%
df_ctd_copy
# Out:
#          ID                                          NOMB_PROY COD_PROY  \
# 0         1  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 1         2  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 2         3  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 3         4  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 4         5  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# ...     ...                                                ...      ...
# 83377  6410  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 83378  6411  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 83379  6412  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 83380  6413  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 83381  6414  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
#
#        FECHA_INI  FECHA_TER                 EQUIPO    LATITUD   LONGITUD  \
# 0     2019-05-11 2019-05-11  CTD SeaBird SBE19plus -41.584401 -72.338603
# 1     2019-05-11 2019-05-11  CTD SeaBird SBE19plus -41.584401 -72.338603
# 2     2019-05-11 2019-05-11  CTD SeaBird SBE19plus -41.584401 -72.338603
# 3     2019-05-11 2019-05-11  CTD SeaBird SBE19plus -41.584401 -72.338603
# 4     2019-05-11 2019-05-11  CTD SeaBird SBE19plus -41.584401 -72.338603
# ...          ...        ...                    ...        ...        ...
# 83377 2019-06-20 2019-06-20  CTD SeaBird SBE19plus -46.676652   -73.9255
# 83378 2019-06-20 2019-06-20  CTD SeaBird SBE19plus -46.676652   -73.9255
# 83379 2019-06-20 2019-06-20  CTD SeaBird SBE19plus -46.676652   -73.9255
# 83380 2019-06-20 2019-06-20  CTD SeaBird SBE19plus -46.676652   -73.9255
# 83381 2019-06-20 2019-06-20  CTD SeaBird SBE19plus -46.676652   -73.9255
#
#       PROF_EQ PROF_SECT COD_REG OBSERV SHAPE N_ESTACION HORA_DATO  \
# 0           1       134       X      1   NaN          1  09:05:00
# 1           2       134       X      1   NaN          1  09:05:00
# 2           3       134       X      1   NaN          1  09:05:00
# 3           4       134       X      1   NaN          1  09:05:00
# 4           5       134       X      1   NaN          1  09:05:00
# ...       ...       ...     ...    ...   ...        ...       ...
# 83377     127     135.9      XI     31   NaN         31  14:56:00
# 83378     128     135.9      XI     31   NaN         31  14:56:00
# 83379     129     135.9      XI     31   NaN         31  14:56:00
# 83380     130     135.9      XI     31   NaN         31  14:56:00
# 83381     131     135.9      XI     31   NaN         31  14:56:00
#
#           VARIABLE    VALOR          FECHA_DATO
# 0      TEMPERATURA  12.2883 2019-05-11 09:05:00
# 1      TEMPERATURA  12.0498 2019-05-11 09:05:00
# 2      TEMPERATURA  11.7416 2019-05-11 09:05:00
# 3      TEMPERATURA  11.6439 2019-05-11 09:05:00
# 4      TEMPERATURA  11.5449 2019-05-11 09:05:00
# ...            ...      ...                 ...
# 83377     SILICATO      NaN 2019-06-20 14:56:00
# 83378     SILICATO      NaN 2019-06-20 14:56:00
# 83379     SILICATO      NaN 2019-06-20 14:56:00
# 83380     SILICATO      NaN 2019-06-20 14:56:00
# 83381     SILICATO      NaN 2019-06-20 14:56:00
#
# [83382 rows x 18 columns]

# %%
def limpieza_ctd_compu(df):
    
    try:
        # Eliminamos las filas innecesarias
        df = df.iloc[11:, :]

        # Reiniciamos los indices
        df = df.reset_index(drop=True)

        # Creamos una copia del dataset
        df_ctd_copy = df.copy()

        # Dejamos la primera fila como columna
        df_ctd_copy.columns = df_ctd_copy.iloc[0]

        # Eliminamos la primera fila
        df_ctd_copy = df_ctd_copy.iloc[1:, :]

        # Reiniciamos los indices
        df_ctd_copy = df_ctd_copy.reset_index(drop=True)

        # Agregamos una columna de ID para identificar los datos antes de realizar el Melt
        df_ctd_copy.insert(0, 'ID', df_ctd_copy.index + 1)

        # Renombramos las columnas
        df_ctd_copy = df_ctd_copy.rename(columns={ 'LONGUITUD': 'LONGITUD', 'TEMPERATU': 'TEMPERATURA', 'HORA DATO': 'HORA_DATO', 'OXIGE_ml/L': 'OXIGENO_DIS_ML/L', 'OXIGE_mg/L': 'OXIGENO_DIS_MG/L', 'OXIGE_%sat': 'OXIGENO_DIS_SAT', 'OX_umol/kg': 'OXIGENO_DIS_UMOLKG', 'FLUORESCEN': 'FLUORESCENCIA'})

        # Creamos las columnas fijas y columnas de variables
        columnas_fijas = ['ID', 'NOMB_PROY', 'COD_PROY', 'FECHA_INI', 'FECHA_TER', 'EQUIPO', 'LATITUD', 'LONGITUD', 'PROF_EQU', 'PROF_SECT', 'COD_REG', 'HORA_DATO' , 'ESTACION']
        columnas_variables = ['TEMPERATURA','OXIGENO_DIS_ML/L', 'OXIGENO_DIS_MG/L', 'OXIGENO_DIS_SAT','OXIGENO_DIS_UMOLKG', 'FLUORESCENCIA', 'SALINIDAD', 'ACIDEZ(pH)','TURBID_NTU']

        """
        Realizamos un melt para convertir las columnas de Variables a filas

            Necesita:
            1. Dataframe a cambiar
            2. id_vars : Lista o Tupla de las columnas Fijas
            3. value_vars : Lista o Tupla de las columnas de Variables
            4. var_name : Nombre de la nueva columna de las Variables
            5. value_name : Nombre de la columna con los valores de la columna de Variables

        """

        df_ctd_copy = pd.melt(df_ctd_copy, id_vars=columnas_fijas, value_vars=columnas_variables, var_name='VARIABLE', value_name='VALOR')

        # Convertimos la HORA_DATO a string

        df_ctd_copy['HORA_DATO'] = df_ctd_copy['HORA_DATO'].astype(str)

        # Remplazamos los 'nan' por 00:00:00

        df_ctd_copy['HORA_DATO'] = np.where(df_ctd_copy['HORA_DATO'] == 'nan', '00:00:00', df_ctd_copy['HORA_DATO'])

        # Creamos un campo de FECHA_DATO
        df_ctd_copy['FECHA_DATO'] = df_ctd_copy['FECHA_TER'].dt.strftime('%d/%m/%Y') + ' ' + df_ctd_copy['HORA_DATO']

        # Realizamos un formateo a los campos de fechas
        df_ctd_copy['FECHA_INI'] = pd.to_datetime(df_ctd_copy['FECHA_INI'], format='%d/%m/%Y %H:%M:%S', errors='coerce')
        df_ctd_copy['FECHA_TER'] = pd.to_datetime(df_ctd_copy['FECHA_TER'], format='%d/%m/%Y %H:%M:%S', errors='coerce')
        df_ctd_copy['FECHA_DATO'] = pd.to_datetime(df_ctd_copy['FECHA_DATO'], format='%d/%m/%Y %H:%M:%S', errors='coerce')


        # Cambiamos los NOMB_PROY ,  
        df_ctd_copy['NOMB_PROY'] = 'ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO 2019-2020'

        #Creamos la columna de N_ESTACION obteneiendo los numeros de la columna ESTACION
        df_ctd_copy['N_ESTACION'] = df_ctd_copy['ESTACION'].str.extract(r'(\d+)')

        #Dejamos la columna N_ESTACION como entero 

        df_ctd_copy['N_ESTACION'] = df_ctd_copy['N_ESTACION'].astype(int)



        return df_ctd_copy, columnas_fijas, columnas_variables

    except Exception as e:
        print(f"Ocurrió un error en la función limpieza_ctd: {e}")
        ex = sys.exc_info()[2]
        print("Error en el archivo : " + str(ex.tb_frame) + " En la linea : " + str(ex.tb_lineno))
        
        return None, None, None  # O devuelve un valor que indique el fallo

# %%
df_ctd_compu_copy , columnas_fijas , columnas_variables = limpieza_ctd_compu(df_ctd_compu)

# %%
df_ctd_compu_copy
# Out:
#          ID                                          NOMB_PROY COD_PROY  \
# 0         1  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 1         2  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 2         3  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 3         4  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 4         5  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# ...     ...                                                ...      ...
# 18274  2027  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 18275  2028  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 18276  2029  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 18277  2030  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 18278  2031  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
#
#        FECHA_INI  FECHA_TER                 EQUIPO  LATITUD LONGITUD PROF_EQU  \
# 0     2019-09-10 2019-09-10  CTD SeaBird SBE19plus -42.8624 -73.7122        1
# 1     2019-09-10 2019-09-10  CTD SeaBird SBE19plus -42.8624 -73.7122        2
# 2     2019-09-10 2019-09-10  CTD SeaBird SBE19plus -42.8624 -73.7122        3
# 3     2019-09-10 2019-09-10  CTD SeaBird SBE19plus -42.8624 -73.7122        4
# 4     2019-09-10 2019-09-10  CTD SeaBird SBE19plus -42.8624 -73.7122        5
# ...          ...        ...                    ...      ...      ...      ...
# 18274 2019-11-07 2019-11-07  CTD SeaBird SBE19plus  -43.058  -73.393      181
# 18275 2019-11-07 2019-11-07  CTD SeaBird SBE19plus  -43.058  -73.393      182
# 18276 2019-11-07 2019-11-07  CTD SeaBird SBE19plus  -43.058  -73.393      183
# 18277 2019-11-07 2019-11-07  CTD SeaBird SBE19plus  -43.058  -73.393      184
# 18278 2019-11-07 2019-11-07  CTD SeaBird SBE19plus  -43.058  -73.393      185
#
#       PROF_SECT COD_REG HORA_DATO ESTACION     VARIABLE   VALOR  \
# 0            31       X  14:38:00       E2  TEMPERATURA  10.064
# 1            31       X  14:38:00       E2  TEMPERATURA  10.414
# 2            31       X  14:38:00       E2  TEMPERATURA  10.585
# 3            31       X  14:38:00       E2  TEMPERATURA  10.323
# 4            31       X  14:38:00       E2  TEMPERATURA  10.317
# ...         ...     ...       ...      ...          ...     ...
# 18274       185       X  09:30:00      E27   TURBID_NTU   0.285
# 18275       185       X  09:30:00      E27   TURBID_NTU   0.292
# 18276       185       X  09:30:00      E27   TURBID_NTU    0.32
# 18277       185       X  09:30:00      E27   TURBID_NTU    0.32
# 18278       185       X  09:30:00      E27   TURBID_NTU   0.307
#
#                FECHA_DATO  N_ESTACION
# 0     2019-09-10 14:38:00           2
# 1     2019-09-10 14:38:00           2
# 2     2019-09-10 14:38:00           2
# 3     2019-09-10 14:38:00           2
# 4     2019-09-10 14:38:00           2
# ...                   ...         ...
# 18274 2019-11-07 09:30:00          27
# 18275 2019-11-07 09:30:00          27
# 18276 2019-11-07 09:30:00          27
# 18277 2019-11-07 09:30:00          27
# 18278 2019-11-07 09:30:00          27
#
# [18279 rows x 17 columns]

# %%
df_ctd_compu_copy['VARIABLE'].unique()
# Out:
# array(['TEMPERATURA', 'OXIGENO_DIS_ML/L', 'OXIGENO_DIS_MG/L',
#        'OXIGENO_DIS_SAT', 'OXIGENO_DIS_UMOLKG', 'FLUORESCENCIA',
#        'SALINIDAD', 'ACIDEZ(pH)', 'TURBID_NTU'], dtype=object)

# %%
df_ctd_compu_copy
# Out:
#          ID                                          NOMB_PROY COD_PROY  \
# 0         1  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 1         2  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 2         3  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 3         4  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 4         5  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# ...     ...                                                ...      ...
# 18274  2027  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 18275  2028  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 18276  2029  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 18277  2030  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 18278  2031  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
#
#        FECHA_INI  FECHA_TER                 EQUIPO  LATITUD LONGITUD PROF_EQU  \
# 0     2019-09-10 2019-09-10  CTD SeaBird SBE19plus -42.8624 -73.7122        1
# 1     2019-09-10 2019-09-10  CTD SeaBird SBE19plus -42.8624 -73.7122        2
# 2     2019-09-10 2019-09-10  CTD SeaBird SBE19plus -42.8624 -73.7122        3
# 3     2019-09-10 2019-09-10  CTD SeaBird SBE19plus -42.8624 -73.7122        4
# 4     2019-09-10 2019-09-10  CTD SeaBird SBE19plus -42.8624 -73.7122        5
# ...          ...        ...                    ...      ...      ...      ...
# 18274 2019-11-07 2019-11-07  CTD SeaBird SBE19plus  -43.058  -73.393      181
# 18275 2019-11-07 2019-11-07  CTD SeaBird SBE19plus  -43.058  -73.393      182
# 18276 2019-11-07 2019-11-07  CTD SeaBird SBE19plus  -43.058  -73.393      183
# 18277 2019-11-07 2019-11-07  CTD SeaBird SBE19plus  -43.058  -73.393      184
# 18278 2019-11-07 2019-11-07  CTD SeaBird SBE19plus  -43.058  -73.393      185
#
#       PROF_SECT COD_REG HORA_DATO ESTACION     VARIABLE   VALOR  \
# 0            31       X  14:38:00       E2  TEMPERATURA  10.064
# 1            31       X  14:38:00       E2  TEMPERATURA  10.414
# 2            31       X  14:38:00       E2  TEMPERATURA  10.585
# 3            31       X  14:38:00       E2  TEMPERATURA  10.323
# 4            31       X  14:38:00       E2  TEMPERATURA  10.317
# ...         ...     ...       ...      ...          ...     ...
# 18274       185       X  09:30:00      E27   TURBID_NTU   0.285
# 18275       185       X  09:30:00      E27   TURBID_NTU   0.292
# 18276       185       X  09:30:00      E27   TURBID_NTU    0.32
# 18277       185       X  09:30:00      E27   TURBID_NTU    0.32
# 18278       185       X  09:30:00      E27   TURBID_NTU   0.307
#
#                FECHA_DATO  N_ESTACION
# 0     2019-09-10 14:38:00           2
# 1     2019-09-10 14:38:00           2
# 2     2019-09-10 14:38:00           2
# 3     2019-09-10 14:38:00           2
# 4     2019-09-10 14:38:00           2
# ...                   ...         ...
# 18274 2019-11-07 09:30:00          27
# 18275 2019-11-07 09:30:00          27
# 18276 2019-11-07 09:30:00          27
# 18277 2019-11-07 09:30:00          27
# 18278 2019-11-07 09:30:00          27
#
# [18279 rows x 17 columns]

# %% [markdown]
# # Limpieza de datos CTD COMAU

# %%
df_ctd_comau = pd.read_excel(r'C:\Users\felipe.abarzua\Desktop\DATA_AMBIENTALES\Proyecto Seguimiento Ambiental\2019_P656115\7_BD_CTD_COMAU_2019.xlsx' , sheet_name='COMAU_JUN_AGOS_DIC_FEB_2019-20')

# %%
df_ctd_comau
# Out:
#                                    Nombre del Proyecto:  \
# 0                                  Codigo del Proyecto:
# 1                            Fecha inicio del muestreo:
# 2                               Fecha fin del muestreo:
# 3                                 Equipos de medición:
# 4                                            Variables:
# ...                                                 ...
# 8974  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 8975  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 8976  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 8977  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 8978  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
#
#      ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO 2019 -2020  \
# 0                                               656-115
# 1                                   2019-06-18 00:00:00
# 2                                   2020-02-17 00:00:00
# 3                                 CTD SeaBird SBE19plus
# 4     Temperatura (°C), oxigeno disuelto (ml/L, mg/L...
# ...                                                 ...
# 8974                                            656-115
# 8975                                            656-115
# 8976                                            656-115
# 8977                                            656-115
# 8978                                            656-115
#
#                Unnamed: 2           Unnamed: 3             Unnamed: 4  \
# 0                     NaN                  NaN                    NaN
# 1                     NaN                  NaN                    NaN
# 2                     NaN                  NaN                    NaN
# 3                     NaN                  NaN                    NaN
# 4                     NaN                  NaN                    NaN
# ...                   ...                  ...                    ...
# 8974  2020-02-17 00:00:00  2020-02-17 00:00:00  CTD SeaBird SBE19plus
# 8975  2020-02-17 00:00:00  2020-02-17 00:00:00  CTD SeaBird SBE19plus
# 8976  2020-02-17 00:00:00  2020-02-17 00:00:00  CTD SeaBird SBE19plus
# 8977  2020-02-17 00:00:00  2020-02-17 00:00:00  CTD SeaBird SBE19plus
# 8978  2020-02-17 00:00:00  2020-02-17 00:00:00  CTD SeaBird SBE19plus
#
#      Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0           NaN        NaN        NaN        NaN        NaN         NaN
# 1           NaN        NaN        NaN        NaN        NaN         NaN
# 2           NaN        NaN        NaN        NaN        NaN         NaN
# 3           NaN        NaN        NaN        NaN        NaN         NaN
# 4           NaN        NaN        NaN        NaN        NaN         NaN
# ...         ...        ...        ...        ...        ...         ...
# 8974  -42.37614  -72.45074        294        298    11.1462      3.2715
# 8975  -42.37614  -72.45074        295        298    11.1507      3.2648
# 8976  -42.37614  -72.45074        296        298    11.1554      3.2614
# 8977  -42.37614  -72.45074        297        298    11.1579       3.259
# 8978  -42.37614  -72.45074        298        298    11.1598      3.2504
#
#      Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 8974      4.6752      52.387     142.528      0.0425     32.8362           X
# 8975      4.6657      52.281      142.24      0.0517     32.8393           X
# 8976      4.6608      52.226     142.089      0.0491     32.8405           X
# 8977      4.6575      52.189     141.988       0.058     32.8407           X
# 8978      4.6452       52.05     141.613      0.0484     32.8404           X
#
#      Unnamed: 17 Unnamed: 18
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# ...          ...         ...
# 8974           1    20:54:00
# 8975           1    20:54:00
# 8976           1    20:54:00
# 8977           1    20:54:00
# 8978           1    20:54:00
#
# [8979 rows x 19 columns]

# %%
def limpieza_ctd_comau(df):
    
    try:
        # Eliminamos las filas innecesarias
        df = df.iloc[12:, :]

        # Reiniciamos los indices
        df = df.reset_index(drop=True)

        # Creamos una copia del dataset
        df_ctd_copy = df.copy()

        # Dejamos la primera fila como columna
        df_ctd_copy.columns = df_ctd_copy.iloc[0]

        # Eliminamos la primera fila
        df_ctd_copy = df_ctd_copy.iloc[1:, :]

        # Reiniciamos los indices
        df_ctd_copy = df_ctd_copy.reset_index(drop=True)

        # Agregamos una columna de ID para identificar los datos antes de realizar el Melt
        df_ctd_copy.insert(0, 'ID', df_ctd_copy.index + 1)

        # Renombramos las columnas
        df_ctd_copy = df_ctd_copy.rename(columns={'LONGUITUD': 'LONGITUD', 'TEMPERATU': 'TEMPERATURA', 'HORA DATO': 'HORA_DATO', 'OXIGE_ml/L': 'OXIGENO_DIS_ML/L', 'OXIGE_mg/L': 'OXIGENO_DIS_MG/L', 'OXIGE_%sat': 'OXIGENO_DIS_SAT', 'OX_umol/kg': 'OXIGENO_DIS_UMOLKG', 'FLUORESCEN': 'FLUORESCENCIA'})

        #Creamos una lista de columnas obtenidas desde el dataframe
        columnas = df_ctd_copy.columns.to_list()

        # Creamos dos listas donde obtiene hasta los primeros 10 elementos de la lista columnas más los ultimos 3 elementos de la lista columnas
        primeros_diez_elementos = columnas[:10]
        ultimos_tres_elementos = columnas[-3:]

        # Creamos las columnas fijas 
        columnas_fijas = primeros_diez_elementos + ultimos_tres_elementos
        
        #Luego creamos la lista de columnas de variables donde parte desde el elemento 10 hasta antes de los ultimos 3 elementos
        columnas_variables = columnas[10:-3]

        """

        Realizamos un melt para convertir las columnas de Variables a filas

            Necesita:
            1. Dataframe a cambiar
            2. id_vars : Lista o Tupla de las columnas Fijas
            3. value_vars : Lista o Tupla de las columnas de Variables
            4. var_name : Nombre de la nueva columna de las Variables
            5. value_name : Nombre de la columna con los valores de la columna de Variables

        """

        df_ctd_copy = pd.melt(df_ctd_copy, id_vars=columnas_fijas, value_vars=columnas_variables, var_name='VARIABLE', value_name='VALOR')

        # Convertimos la HORA_DATO a string
        df_ctd_copy['HORA_DATO'] = df_ctd_copy['HORA_DATO'].astype(str)

        # Remplazamos los 'nan' por 00:00:00
        df_ctd_copy['HORA_DATO'] = np.where(df_ctd_copy['HORA_DATO'] == 'nan', '00:00:00', df_ctd_copy['HORA_DATO'])

        # Creamos un campo de FECHA_DATO
        df_ctd_copy['FECHA_DATO'] = df_ctd_copy['FECHA_TER'].dt.strftime('%d/%m/%Y') + ' ' + df_ctd_copy['HORA_DATO']

        # Realizamos un formateo a los campos de fechas
        df_ctd_copy['FECHA_INI'] = pd.to_datetime(df_ctd_copy['FECHA_INI'], format='%d/%m/%Y %H:%M:%S', errors='coerce')
        df_ctd_copy['FECHA_TER'] = pd.to_datetime(df_ctd_copy['FECHA_TER'], format='%d/%m/%Y %H:%M:%S', errors='coerce')
        df_ctd_copy['FECHA_DATO'] = pd.to_datetime(df_ctd_copy['FECHA_DATO'], format='%d/%m/%Y %H:%M:%S', errors='coerce')
     

        #Renombramos los NOMB_PROY

        df_ctd_copy['NOMB_PROY'] = 'ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO 2019-2020'

    
        return df_ctd_copy, columnas , columnas_fijas , columnas_variables

    except Exception as e:
        print(f"Ocurrió un error en la función limpieza_ctd: {e}")
        ex = sys.exc_info()[2]
        print("Error en el archivo : " + str(ex.tb_frame) + " En la linea : " + str(ex.tb_lineno))
        
        return None, None, None  # O devuelve un valor que indique el fallo

# %%
df_ctd_comau_copy , columnas , columnas_fijas , columnas_variables = limpieza_ctd_comau(df_ctd_comau)

# %%
df_ctd_comau_copy.columns
# Out:
# Index(['ID', 'NOMB_PROY', 'COD_PROY', 'FECHA_INI', 'FECHA_TER', 'EQUIPO',
#        'LATITUD', 'LONGITUD', 'PROF_EQU', 'PROF_SECT', 'COD_REG', 'ESTACION',
#        'HORA_DATO', 'VARIABLE', 'VALOR', 'FECHA_DATO'],
#       dtype='object')

# %%
df_ctd_comau_copy['NOMB_PROY'].unique()
# Out:
# array(['ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO 2019-2020'],
#       dtype=object)

# %%
df_ctd_comau_copy['EQUIPO'].unique()
# Out:
# array(['CTD SeaBird SBE19plus'], dtype=object)

# %% [markdown]
# # Limpieza de datos de BD_Compu_PH_RX

# %%
df_compu_ph = pd.read_excel(r'C:\Users\felipe.abarzua\Desktop\DATA_AMBIENTALES\Proyecto Seguimiento Ambiental\2019_P656115\4_BD_COMPU_ph_Rx_T_2019.xlsx' ,  sheet_name= 'COMPU_sept_nov_feb_19')

# %%
def limpieza_ph(df):
      
    try:

        #Eliminamos las filas y columnas innecesarias 

        df =  df.iloc[13: , :-2]

        #Realizamos una copia del dataset
        df_ph_copy = df.copy()

        #Reiniciamos los indices del dataframe
        df_ph_copy = df_ph_copy.reset_index(drop=True)

        #Dejamos la primera fila como columnas del dataframe
        df_ph_copy.columns = df_ph_copy.iloc[0]

        #Eliminamos la primera fila del dataframe 
        df_ph_copy = df_ph_copy.iloc[1: , :]

        #Reiniciamos los indices del dataframe
        df_ph_copy = df_ph_copy.reset_index(drop=True)

        #Renombramos las columnas del dataframe 
        df_ph_copy = df_ph_copy.rename(columns={'LONGUITUD' : 'LONGITUD'})

        #Creamos una columna ID en la primera columna del dataframe
        df_ph_copy.insert(0 , 'ID' , df_ph_copy.index + 1)

        #Creamos la lista de columnas
        columnas = df_ph_copy.columns.to_list()

        #Creamos las columnas fijas y las columnas de variables

        columnas_fijas = columnas[:16]
        columnas_variables = columnas[16:]

        """
              Realizamos un melt para convertir las columnas de Variables a filas

            Necesita:
            1. Dataframe a cambiar
            2. id_vars : Lista o Tupla de las columnas Fijas
            3. value_vars : Lista o Tupla de las columnas de Variables
            4. var_name : Nombre de la nueva columna de las Variables
            5. value_name : Nombre de la columna con los valores de la columna de Variables


        """

        df_ph_copy = pd.melt(df_ph_copy , id_vars=columnas_fijas , value_vars=columnas_variables , var_name= "COLUMNA_VARIABLES" , value_name= "VALOR" )


        #Cambiamos el tipo de dato de la columna FECHA_INICIO a string

        df_ph_copy['FECHA_INI'] = df_ph_copy['FECHA_INI'].astype(str)
        df_ph_copy['HORA_INI'] = df_ph_copy['HORA_INI'].astype(str)

        #Cambiamos los nan de la columna HORA_INI a 00:00:00
        
        df_ph_copy['HORA_INI'] = np.where(df_ph_copy['HORA_INI'] == 'nan' , '00:00:00' , df_ph_copy['HORA_INI'])

        #Creamos una columna de FECHA_INICIO y FECHA_TERMINO

        df_ph_copy['FECHA_INICIO'] = pd.to_datetime(df_ph_copy['FECHA_INI'] + ' ' + df_ph_copy['HORA_INI'], format='%Y-%m-%d %H:%M:%S', errors='coerce')
       
        #Cambiamos el formato de la fecha
        df_ph_copy['FECHA_INICIO'] = df_ph_copy['FECHA_INICIO'].dt.strftime('%d/%m/%Y %H:%M:%S')


        #
        df_ph_copy['NOMB_PROY'] = 'ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO 2019-2020'

          #Dejamos la columna de variables en mayuscula 

        df_ph_copy['COLUMNA_VARIABLES'] = df_ph_copy['COLUMNA_VARIABLES'].str.upper()

        #Reemplazamos los valores de la columna VARIABLES

        df_ph_copy['COLUMNA_VARIABLES'] = np.where(df_ph_copy['COLUMNA_VARIABLES'] == 'MAT_ORG' , 'MATERIA ORGANICA' , df_ph_copy['COLUMNA_VARIABLES'])
        df_ph_copy['COLUMNA_VARIABLES'] = np.where(df_ph_copy['COLUMNA_VARIABLES'] == 'DIV_SHANNON' , 'DISIDAD DE SHANNON' , df_ph_copy['COLUMNA_VARIABLES'])
        df_ph_copy['COLUMNA_VARIABLES'] = np.where(df_ph_copy['COLUMNA_VARIABLES'] == 'BIOM_TOTAL' , 'BIOMASA TOTAL' , df_ph_copy['COLUMNA_VARIABLES'])
        df_ph_copy['COLUMNA_VARIABLES'] = np.where(df_ph_copy['COLUMNA_VARIABLES'] == 'UNIF_PIELOU' , 'UNIFORMIDAD DE PIELOU' , df_ph_copy['COLUMNA_VARIABLES'])
        df_ph_copy['COLUMNA_VARIABLES'] = np.where(df_ph_copy['COLUMNA_VARIABLES'] == 'CLASIF_PERTURB' , 'CLASIFICACIÓN DE PERTURBACIÓN' , df_ph_copy['COLUMNA_VARIABLES'])
        df_ph_copy['COLUMNA_VARIABLES'] = np.where(df_ph_copy['COLUMNA_VARIABLES'] == 'N°_TAXA' , 'NUMERO DE TAXA' , df_ph_copy['COLUMNA_VARIABLES'])
        df_ph_copy['COLUMNA_VARIABLES'] = np.where(df_ph_copy['COLUMNA_VARIABLES'] == 'TEMP_REPL1' , 'TEMP_REPL_1' , df_ph_copy['COLUMNA_VARIABLES'])
        df_ph_copy['COLUMNA_VARIABLES'] = np.where(df_ph_copy['COLUMNA_VARIABLES'] == 'TEMP_REPL2' , 'TEMP_REPL_2' , df_ph_copy['COLUMNA_VARIABLES'])
        df_ph_copy['COLUMNA_VARIABLES'] = np.where(df_ph_copy['COLUMNA_VARIABLES'] == 'TEMP_REPL3' , 'TEMP_REPL_3' , df_ph_copy['COLUMNA_VARIABLES'])


        #Eliminamos las columnas innecesarias

        df_ph_copy = df_ph_copy[['ID', 'NOMB_PROY', 'COD_PROY', 'ETAP_PROY', 'JEFE_PROY', 'INST_PROY',
       'NOM_SECTOR', 'COD_REG', 'FECHA_INI', 'FECHA_TER','HORA_INI', 'N_ESTACION', 'LATITUD', 'LONGITUD', 'PROF_SECT',
       'COLUMNA_VARIABLES', 'VALOR', 'FECHA_INICIO']]

      
        df_ph_copy['ORIGEN'] = 'BD_COMPU_ph_Rx_T_2019'

        df_ph_copy['FECHA_INICIO'] = pd.to_datetime(df_ph_copy['FECHA_INICIO'], format='%d/%m/%Y %H:%M:%S')


        
        return df_ph_copy , columnas , columnas_fijas , columnas_variables

    except Exception as e:
        print(f"Ocurrió un error en la función limpieza_ctd: {e}")
        ex = sys.exc_info()[2]
        print("Error en el archivo : " + str(ex.tb_frame) + " En la linea : " + str(ex.tb_lineno))
            
        return None  # O devuelve un valor que indique el fallo

# %%
df_ph_copy , columnas , columnas_fijas , columnas_variables = limpieza_ph(df_compu_ph)

# %%
df_ph_copy['FECHA_INICIO'].unique()
# Out:
# <DatetimeArray>
# ['2019-09-13 19:07:00', '2019-09-13 19:26:00', '2019-09-13 19:36:00',
#  '2019-09-13 18:09:00', '2019-09-13 18:29:00', '2019-09-13 18:51:00',
#  '2019-09-13 17:50:00', '2019-09-13 16:52:00', '2019-09-13 16:57:00',
#  '2019-09-13 16:40:00', '2019-09-13 21:55:00', '2019-09-13 21:50:00',
#  '2019-09-13 21:30:00', '2019-09-13 14:45:00', '2019-09-13 18:57:00',
#  '2019-11-08 00:00:00', '2019-11-07 00:00:00', '2020-02-06 09:54:00',
#  '2020-02-06 10:08:00', '2020-02-06 10:39:00', '2020-02-06 10:54:00',
#  '2020-02-06 11:20:00', '2020-02-06 11:35:00', '2020-02-06 12:16:00',
#  '2020-02-06 12:43:00', '2020-02-06 13:02:00', '2020-02-06 13:40:00',
#  '2020-02-06 15:24:00', '2020-02-05 19:14:00', '2020-02-06 15:40:00',
#  '2020-02-06 16:15:00', '2020-02-05 19:38:00', '2020-02-05 17:31:00',
#  '2020-02-05 18:37:00', '2020-02-06 09:33:00', '2020-02-05 10:45:00',
#  '2020-02-05 14:31:00']
# Length: 37, dtype: datetime64[ns]

# %%
df_ph_copy['COLUMNA_VARIABLES'].unique()
# Out:
# array(['PROF_VAR', 'PH_REPL_1', 'PH_REPL_2', 'PH_REPL_3', 'TEMP_REPL_1',
#        'TEMP_REPL_2', 'TEMP_REPL_3', 'REDOX_REPL_1', 'REDOX_REPL_2',
#        'REDOX_REPL_3'], dtype=object)

# %% [markdown]
# # Limpieza de datos de PH_RX_T

# %%
df_comau_ph = pd.read_excel(r'C:\Users\felipe.abarzua\Desktop\DATA_AMBIENTALES\Proyecto Seguimiento Ambiental\2019_P656115\5_BD_COMAU_ph_Rx_T_2019.xlsx' , sheet_name = 'Fiordo Comau dic_ene_feb')

# %%
df_comau_ph[14:]
# Out:
#                                  Nombre del Proyecto:  \
# 14                                          NOMB_PROY
# 15  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 16  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 17  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 18  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# ..                                                ...
# 82  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 83  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 84  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 85  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 86  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
#
#    ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO 2019 -2020  \
# 14                                           COD_PROY
# 15                                            656-115
# 16                                            656-115
# 17                                            656-115
# 18                                            656-115
# ..                                                ...
# 82                                            656-115
# 83                                            656-115
# 84                                            656-115
# 85                                            656-115
# 86                                            656-115
#
#                                            Unnamed: 2    Unnamed: 3  \
# 14                                          ETAP_PROY     JEFE_PROY
# 15  Objetivo 3. Actividad 5. Muestreos y Analisis ...  GASTON VIDAL
# 16  Objetivo 3. Actividad 5. Muestreos y Analisis ...  GASTON VIDAL
# 17  Objetivo 3. Actividad 5. Muestreos y Analisis ...  GASTON VIDAL
# 18  Objetivo 3. Actividad 5. Muestreos y Analisis ...  GASTON VIDAL
# ..                                                ...           ...
# 82  Objetivo 3. Actividad 5. Muestreos y Analisis ...  GASTON VIDAL
# 83  Objetivo 3. Actividad 5. Muestreos y Analisis ...  GASTON VIDAL
# 84  Objetivo 3. Actividad 5. Muestreos y Analisis ...  GASTON VIDAL
# 85  Objetivo 3. Actividad 5. Muestreos y Analisis ...  GASTON VIDAL
# 86  Objetivo 3. Actividad 5. Muestreos y Analisis ...  GASTON VIDAL
#
#                        Unnamed: 4    Unnamed: 5 Unnamed: 6  \
# 14                      INST_PROY    NOM_SECTOR    COD_REG
# 15  INSTITUTO DE FOMENTO PESQUERO  FIORDO COMAU          X
# 16  INSTITUTO DE FOMENTO PESQUERO  FIORDO COMAU          X
# 17  INSTITUTO DE FOMENTO PESQUERO  FIORDO COMAU          X
# 18  INSTITUTO DE FOMENTO PESQUERO  FIORDO COMAU          X
# ..                            ...           ...        ...
# 82  INSTITUTO DE FOMENTO PESQUERO  FIORDO COMAU          X
# 83  INSTITUTO DE FOMENTO PESQUERO  FIORDO COMAU          X
# 84  INSTITUTO DE FOMENTO PESQUERO  FIORDO COMAU          X
# 85  INSTITUTO DE FOMENTO PESQUERO  FIORDO COMAU          X
# 86  INSTITUTO DE FOMENTO PESQUERO  FIORDO COMAU          X
#
#                                            Unnamed: 7           Unnamed: 8  \
# 14                                          VARIABLES            FECHA_INI
# 15  Ph, Temperatura (°C), Redox EHNHE (mV), Sulfur...  2019-12-18 00:00:00
# 16  Ph, Temperatura (°C), Redox EHNHE (mV), Sulfur...  2019-12-18 00:00:00
# 17  Ph, Temperatura (°C), Redox EHNHE (mV), Sulfur...                  NaN
# 18  Ph, Temperatura (°C), Redox EHNHE (mV), Sulfur...  2019-12-18 00:00:00
# ..                                                ...                  ...
# 82  Ph, Temperatura (°C), Redox EHNHE (mV), Sulfur...                  NaN
# 83  Ph, Temperatura (°C), Redox EHNHE (mV), Sulfur...  2020-02-19 00:00:00
# 84  Ph, Temperatura (°C), Redox EHNHE (mV), Sulfur...  2020-02-22 00:00:00
# 85  Ph, Temperatura (°C), Redox EHNHE (mV), Sulfur...  2020-02-22 00:00:00
# 86  Ph, Temperatura (°C), Redox EHNHE (mV), Sulfur...  2020-02-22 00:00:00
#
#              Unnamed: 9  ...   Unnamed: 24  Unnamed: 25  Unnamed: 26  \
# 14            FECHA_TER  ...  REDOX_REPL_3  SULF_REPL_1  SULF_REPL_2
# 15  2019-12-18 00:00:00  ...         115.3     6.698682    17.400617
# 16  2019-12-18 00:00:00  ...         127.4     0.006748     0.019024
# 17                  NaN  ...           NaN          NaN          NaN
# 18  2019-12-18 00:00:00  ...         127.3     0.307258     0.000515
# ..                  ...  ...           ...          ...          ...
# 82                  NaN  ...           NaN          NaN          NaN
# 83  2020-02-19 00:00:00  ...         325.2    64.465021    57.773858
# 84  2020-02-22 00:00:00  ...         369.6          NaN          NaN
# 85  2020-02-22 00:00:00  ...         445.1          NaN          NaN
# 86  2020-02-22 00:00:00  ...         208.5          NaN          NaN
#
#     Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31  \
# 14  SULF_REPL_3     MAT_ORG    COT_mg C    COT_ug C      COT_%C
# 15     5.288501     2.16703    0.116865  116.865086    1.036314
# 16     0.059273    4.743555    0.175147  175.147226    1.687515
# 17          NaN         NaN         NaN         NaN         NaN
# 18     0.290947    3.024056    0.146075  146.074817    1.268671
# ..          ...         ...         ...         ...         ...
# 82          NaN         NaN         NaN         NaN         NaN
# 83     92.40603    1.786108    0.105689  105.689033    0.912607
# 84          NaN    1.369558    0.099622   99.622081    0.869454
# 85          NaN    2.148077    0.113969  113.968507    0.931344
# 86          NaN    4.530907    0.180995  180.994972    1.731512
#
#                                           Unnamed: 32 Unnamed: 33
# 14                                             OBSERV       SHAPE
# 15                                         Arena fina         NaN
# 16                                         Arena fina         NaN
# 17  Sin muestra. Ajustes en las estaciones de mues...         NaN
# 18                                         Arena fina         NaN
# ..                                                ...         ...
# 82                                                NaN         NaN
# 83                            Arena fina y conchillas         NaN
# 84                                          Conchilla         NaN
# 85                                          Conchilla         NaN
# 86                                          Conchilla         NaN
#
# [73 rows x 34 columns]

# %%
def limpieza_ph_comau(df):

    try:
        #Eliminamos las filas innecesarias
        df = df.iloc[14: , :-1]

        #Realizamos copia del dataset
        df_ph_copy = df.copy()

        #Reiniciamos los indices del dataset
        df_ph_copy = df_ph_copy.reset_index(drop=True)

        #Dejamos la primera fila como columna
        df_ph_copy.columns = df_ph_copy.iloc[0]

        #Eliminamos la primera fila 
        df_ph_copy = df_ph_copy.iloc[1: , :]

        #reiniciamos los indices
        df_ph_copy = df_ph_copy.reset_index(drop=True)

        #Creamos una columna de id 
        df_ph_copy.insert(0 , 'ID' , df_ph_copy.index + 1)

        #Renombramos las columnas del dataframe
        df_ph_copy = df_ph_copy.rename(columns={' COT_mg C' : 'COT_mg_C' , 'LONGUITUD' : 'LONGITUD' , 'COT_ug C' : 'COT_ug_C'})

        #Creamos una lista de columnas
        columnas = df_ph_copy.columns.to_list()

        #Creamos dos listas para despues unirlas para crear las columnas fijas
        columnas_fijas_1 = columnas[:16] 
        columnas_fijas_2 = columnas[-1:]

        columnas_fijas = columnas_fijas_1 + columnas_fijas_2
        columnas_variables = columnas[16:-1]

        
        """
              Realizamos un melt para convertir las columnas de Variables a filas

            Necesita:
            1. Dataframe a cambiar
            2. id_vars : Lista o Tupla de las columnas Fijas
            3. value_vars : Lista o Tupla de las columnas de Variables
            4. var_name : Nombre de la nueva columna de las Variables
            5. value_name : Nombre de la columna con los valores de la columna de Variables


        """

        df_ph_copy = pd.melt(df_ph_copy , id_vars= columnas_fijas , value_vars= columnas_variables , var_name = 'COLUMNA_VARIABLES' , value_name= 'VALOR' )

        #Cambiamos la columna HORA_INI
        df_ph_copy['HORA_INI'] = df_ph_copy['HORA_INI'].astype(str)

        #Reemplazamos los nan de la HORA_INI por 00:00:00
        df_ph_copy['HORA_INI'] = np.where(df_ph_copy['HORA_INI'] == 'nan' , '00:00:00' , df_ph_copy['HORA_INI'])

        #Creamos una columna de FECHA_INICIO
    
        df_ph_copy.insert(12 , 'FECHA_INICIO' , pd.to_datetime(df_ph_copy['FECHA_INI'].dt.strftime('%Y-%m-%d') + ' ' + df_ph_copy['HORA_INI']) )

        #Formateamos la columna FECHA_INICIO a DD/MM/YYYY HH:MI:SS
        df_ph_copy['FECHA_INICIO'] = pd.to_datetime(df_ph_copy['FECHA_INICIO'] ,  format='%d/%m/%Y %H:%M:%S')



        #Cambiamos el nombre de la columna 
        df_ph_copy['NOMB_PROY'] = 'ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO 2019-2020'


        #Dejamos la columna de variables en mayuscula 

        df_ph_copy['COLUMNA_VARIABLES'] = df_ph_copy['COLUMNA_VARIABLES'].str.upper()

        #Reemplazamos los valores de la columna VARIABLES

        df_ph_copy['COLUMNA_VARIABLES'] = np.where(df_ph_copy['COLUMNA_VARIABLES'] == 'MAT_ORG' , 'MATERIA ORGANICA' , df_ph_copy['COLUMNA_VARIABLES'])
        df_ph_copy['COLUMNA_VARIABLES'] = np.where(df_ph_copy['COLUMNA_VARIABLES'] == 'DIV_SHANNON' , 'DISIDAD DE SHANNON' , df_ph_copy['COLUMNA_VARIABLES'])
        df_ph_copy['COLUMNA_VARIABLES'] = np.where(df_ph_copy['COLUMNA_VARIABLES'] == 'BIOM_TOTAL' , 'BIOMASA TOTAL' , df_ph_copy['COLUMNA_VARIABLES'])
        df_ph_copy['COLUMNA_VARIABLES'] = np.where(df_ph_copy['COLUMNA_VARIABLES'] == 'UNIF_PIELOU' , 'UNIFORMIDAD DE PIELOU' , df_ph_copy['COLUMNA_VARIABLES'])
        df_ph_copy['COLUMNA_VARIABLES'] = np.where(df_ph_copy['COLUMNA_VARIABLES'] == 'CLASIF_PERTURB' , 'CLASIFICACIÓN DE PERTURBACIÓN' , df_ph_copy['COLUMNA_VARIABLES'])
        df_ph_copy['COLUMNA_VARIABLES'] = np.where(df_ph_copy['COLUMNA_VARIABLES'] == 'N°_TAXA' , 'NUMERO DE TAXA' , df_ph_copy['COLUMNA_VARIABLES'])
        
        
        #Eliminamos las columnas innecesarias

        df_ph_copy = df_ph_copy[['ID', 'NOMB_PROY', 'COD_PROY', 'ETAP_PROY', 'JEFE_PROY', 'INST_PROY',    'NOM_SECTOR', 'COD_REG', 'FECHA_INI', 'FECHA_TER',
       'HORA_INI', 'FECHA_INICIO', 'N_ESTACION', 'LATITUD', 'LONGITUD', 'PROF_SECT', 'COLUMNA_VARIABLES', 'VALOR']]



        df_ph_copy['FECHA_INICIO'] = df_ph_copy['FECHA_INICIO'].dt.strftime('%d/%m/%Y %H:%M:%S')

        df_ph_copy['ORIGEN'] = 'BD_COMAU_ph_Rx_T_2019'


        return df_ph_copy , columnas , columnas_fijas ,  columnas_variables

    
    except Exception as e:
        print(f"Ocurrió un error en la función limpieza_ph_comau: {e}")
        ex = sys.exc_info()[2]
        print("Error en el archivo : " + str(ex.tb_frame) + " En la linea : " + str(ex.tb_lineno))
            
        return None  # O devuelve un valor que indique el fallo

# %%
df_comau_ph_copy , columnas , columnas_fijas , columnas_variables= limpieza_ph_comau(df_comau_ph)

# %%
df_comau_ph_copy['FECHA_INICIO'].unique()
# Out:
# array(['18/12/2019 17:05:00', '18/12/2019 18:36:00', nan,
#        '18/12/2019 16:09:00', '18/12/2019 14:49:00',
#        '18/12/2019 10:00:00', '18/12/2019 10:35:00',
#        '18/12/2019 12:13:00', '17/12/2019 09:40:00',
#        '17/12/2019 11:23:00', '16/12/2019 18:30:00',
#        '16/12/2019 17:33:00', '16/12/2019 17:09:00',
#        '16/12/2019 11:57:00', '16/12/2019 11:33:00',
#        '16/12/2019 09:10:00', '15/12/2019 16:38:00',
#        '15/12/2019 18:05:00', '17/12/2019 13:47:00',
#        '17/12/2019 14:20:00', '17/12/2019 16:15:00',
#        '04/02/2020 09:10:00', '04/02/2020 09:37:00',
#        '03/02/2020 16:58:00', '03/02/2020 17:32:00',
#        '03/02/2020 14:31:00', '03/02/2020 15:05:00',
#        '03/02/2020 15:54:00', '02/02/2020 13:47:00',
#        '02/02/2020 14:43:00', '02/02/2020 10:04:00',
#        '02/02/2020 09:24:00', '02/02/2020 08:29:00',
#        '01/02/2020 12:47:00', '01/02/2020 08:20:00',
#        '31/01/2020 19:09:00', '31/01/2020 15:47:00',
#        '31/01/2020 17:51:00', '02/02/2020 15:14:00',
#        '02/02/2020 16:44:00', '02/02/2020 18:50:00',
#        '26/02/2020 08:59:00', '26/02/2020 09:47:00',
#        '25/02/2020 09:53:00', '25/02/2020 11:59:00',
#        '21/02/2020 09:31:00', '21/02/2020 12:12:00',
#        '22/02/2020 18:00:00', '20/02/2020 18:24:00',
#        '20/02/2020 11:20:00', '20/02/2020 10:12:00',
#        '20/02/2020 08:48:00', '20/02/2020 14:53:00',
#        '19/02/2020 16:52:00', '19/02/2020 14:39:00',
#        '19/02/2020 08:11:00', '19/02/2020 11:03:00',
#        '22/02/2020 14:58:00', '22/02/2020 11:06:00',
#        '22/02/2020 09:58:00'], dtype=object)

# %% [markdown]
# # Limpieza BD Muestreo Regular Seguimiento 2019

# %%
df_muestreo_regular = pd.read_excel(r'C:\Users\felipe.abarzua\Desktop\DATA_AMBIENTALES\Proyecto Seguimiento Ambiental\2019_P656115\1_BD_MuestreoRegular_SEGUIMIENTO_2019.xlsx' , sheet_name='BD_Seguimiento_Ambiental_IFOP19')

# %%
df_muestreo_regular
# Out:
#                                   Nombre del Proyecto:  \
# 0                                 Codigo del Proyecto:
# 1                                      Etapa Proyecto:
# 2                                        Jefe Proyecto
# 3                                        Institucion:
# 4                                      Nombre Sector:
# ..                                                 ...
# 181  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 182  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 183  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 184  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 185  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
#
#     ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO 2019 -2020  \
# 0                                              656-115
# 1    Objetivo 1. Actividad 2. Muestreos y Analisis ...
# 2                                         Gastón Vidal
# 3                        INSTITUTO DE FOMENTO PESQUERO
# 4    Atacama (Caldera-Bahia Inglesa), Coquimbo (Ton...
# ..                                                 ...
# 181                                            656-115
# 182                                            656-115
# 183                                            656-115
# 184                                            656-115
# 185                                            656-115
#
#                                             Unnamed: 2    Unnamed: 3  \
# 0                                                  NaN           NaN
# 1                                                  NaN           NaN
# 2                                                  NaN           NaN
# 3                                                  NaN           NaN
# 4                                                  NaN           NaN
# ..                                                 ...           ...
# 181  Objetivo 1. Actividad 2. Muestreos y Analisis ...  GASTON VIDAL
# 182  Objetivo 1. Actividad 2. Muestreos y Analisis ...  GASTON VIDAL
# 183  Objetivo 1. Actividad 2. Muestreos y Analisis ...  GASTON VIDAL
# 184  Objetivo 1. Actividad 2. Muestreos y Analisis ...  GASTON VIDAL
# 185  Objetivo 1. Actividad 2. Muestreos y Analisis ...  GASTON VIDAL
#
#                         Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                              NaN        NaN        NaN
# 1                              NaN        NaN        NaN
# 2                              NaN        NaN        NaN
# 3                              NaN        NaN        NaN
# 4                              NaN        NaN        NaN
# ..                             ...        ...        ...
# 181  INSTITUTO DE FOMENTO PESQUERO    Natales        XII
# 182  INSTITUTO DE FOMENTO PESQUERO    Natales        XII
# 183  INSTITUTO DE FOMENTO PESQUERO    Natales        XII
# 184  INSTITUTO DE FOMENTO PESQUERO    Natales        XII
# 185  INSTITUTO DE FOMENTO PESQUERO    Natales        XII
#
#                                             Unnamed: 7           Unnamed: 8  \
# 0                                                  NaN                  NaN
# 1                                                  NaN                  NaN
# 2                                                  NaN                  NaN
# 3                                                  NaN                  NaN
# 4                                                  NaN                  NaN
# ..                                                 ...                  ...
# 181  Ph, Temperatura (°C), Redox EHNHE (mV), Sulfur...  2019-08-11 00:00:00
# 182  Ph, Temperatura (°C), Redox EHNHE (mV), Sulfur...  2019-08-11 00:00:00
# 183  Ph, Temperatura (°C), Redox EHNHE (mV), Sulfur...  2019-08-11 00:00:00
# 184  Ph, Temperatura (°C), Redox EHNHE (mV), Sulfur...  2019-08-11 00:00:00
# 185  Ph, Temperatura (°C), Redox EHNHE (mV), Sulfur...  2019-08-11 00:00:00
#
#               Unnamed: 9  ... Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32  \
# 0                    NaN  ...         NaN         NaN         NaN         NaN
# 1                    NaN  ...         NaN         NaN         NaN         NaN
# 2                    NaN  ...         NaN         NaN         NaN         NaN
# 3                    NaN  ...         NaN         NaN         NaN         NaN
# 4                    NaN  ...         NaN         NaN         NaN         NaN
# ..                   ...  ...         ...         ...         ...         ...
# 181  2019-08-11 00:00:00  ...        1520          13      10.042      0.7994
# 182  2019-08-11 00:00:00  ...         230          11       1.088      0.9806
# 183  2019-08-11 00:00:00  ...         NaN         NaN         NaN         NaN
# 184  2019-08-11 00:00:00  ...        5410          17       4.606      0.4952
# 185  2019-08-11 00:00:00  ...        1610          14       0.996      0.8131
#
#     Unnamed: 33 Unnamed: 34             Unnamed: 35 Unnamed: 36  \
# 0           NaN         NaN                     NaN         NaN
# 1           NaN         NaN                     NaN         NaN
# 2           NaN         NaN                     NaN         NaN
# 3           NaN         NaN                     NaN         NaN
# 4           NaN         NaN                     NaN         NaN
# ..          ...         ...                     ...         ...
# 181      0.7176       1.283  Ligeramente perturbado         NaN
# 182      0.9416       1.705  Ligeramente perturbado         NaN
# 183         NaN         NaN                     NaN         NaN
# 184      0.4025       1.912  Ligeramente perturbado         NaN
# 185      0.7094       1.488  Ligeramente perturbado         NaN
#
#                                Unnamed: 37 Unnamed: 38
# 0                                      NaN         NaN
# 1                                      NaN         NaN
# 2                                      NaN         NaN
# 3                                      NaN         NaN
# 4                                      NaN         NaN
# ..                                     ...         ...
# 181                                    NaN          45
# 182                                    NaN          48
# 183  No corresponde muestra de macrofauna           48
# 184                                    NaN         47a
# 185                                    NaN          46
#
# [186 rows x 39 columns]

# %%
def limpieza_muestreo_regular(df):

    try:
        
        #Eliminamos filas innecesarias
        df = df.iloc[15: , :]

        #Creamos una copia del dataset 
        df_muestreo_regular_copy = df.copy()

        #Reiniciamos los indices del dataframe
        df_muestreo_regular_copy = df_muestreo_regular_copy.reset_index(drop = True)

        #Dejamos la primera fila como columnas 
        df_muestreo_regular_copy.columns = df_muestreo_regular_copy.iloc[0]

        #Eliminamos la primera fila del dataframe 
        df_muestreo_regular_copy = df_muestreo_regular_copy.iloc[1: , :]

        #Volvemos a reiniciar los indices del dataframe
        df_muestreo_regular_copy = df_muestreo_regular_copy.reset_index(drop = True)

        #Renombramos las columnas 
        df_muestreo_regular_copy =  df_muestreo_regular_copy.rename(columns = {'LONGUITUD' : 'LONGITUD'})

        #Agregamos una columna de ID 
        df_muestreo_regular_copy.insert(0, 'ID' , df_muestreo_regular_copy.index + 1)

        #Creamos una lista de las columnas 
        columnas = df_muestreo_regular_copy.columns.to_list()

        #Creamos la lista de columnas fijas y variables
        columnas_fijas_1 = columnas[:16]
        columnas_fijas_2 = columnas[-3:]

        columnas_fijas = columnas_fijas_1 + columnas_fijas_2
        columnas_variables = columnas[16:]

              
        """
              Realizamos un melt para convertir las columnas de Variables a filas

            Necesita:
            1. Dataframe a cambiar
            2. id_vars : Lista o Tupla de las columnas Fijas
            3. value_vars : Lista o Tupla de las columnas de Variables
            4. var_name : Nombre de la nueva columna de las Variables
            5. value_name : Nombre de la columna con los valores de la columna de Variables


        """

        df_muestreo_regular_copy = pd.melt(df_muestreo_regular_copy , id_vars= columnas_fijas , value_vars=columnas_variables , var_name= 'COLUMNA_VARIABLES' , value_name='VALOR')

        #Cambiamos el tipo de dato de HORA_INI a string 

        df_muestreo_regular_copy['HORA_INI'] =  df_muestreo_regular_copy['HORA_INI'].astype(str)
        
        #Realizamos un replace para cambiar las HORA_INI
        df_muestreo_regular_copy['HORA_INI'] = np.where(df_muestreo_regular_copy['HORA_INI'] == '1927-05-17 23:45:36' , '23:45:36' , df_muestreo_regular_copy['HORA_INI'])
        df_muestreo_regular_copy['HORA_INI'] = np.where(df_muestreo_regular_copy['HORA_INI'] == 'nan' , '00:00:00' , df_muestreo_regular_copy['HORA_INI'])
        
        #Luego creamos una columna llamada FECHA_INICIO 
        df_muestreo_regular_copy.insert(12 , 'FECHA_INICIO' , pd.to_datetime(df_muestreo_regular_copy['FECHA_INI'].dt.strftime('%Y-%m-%d') + ' ' + df_muestreo_regular_copy['HORA_INI'])) 

        #Formateamos la columna FECHA_INICIO a DD/MM/YYYY HH:MI:SS
        df_muestreo_regular_copy['FECHA_INICIO'] = pd.to_datetime(df_muestreo_regular_copy['FECHA_INICIO'] ,  format='%d/%m/%Y %H:%M:%S')

        #Convertimos la columna de VARIABLES a mayuscula

        df_muestreo_regular_copy['COLUMNA_VARIABLES'] = df_muestreo_regular_copy['COLUMNA_VARIABLES'].str.upper()

        #Reemplazamos los valores de la columna VARIABLES

        df_muestreo_regular_copy['COLUMNA_VARIABLES'] = np.where(df_muestreo_regular_copy['COLUMNA_VARIABLES'] == 'MAT_ORG' , 'MATERIA ORGANICA' , df_muestreo_regular_copy['COLUMNA_VARIABLES'])
        df_muestreo_regular_copy['COLUMNA_VARIABLES'] = np.where(df_muestreo_regular_copy['COLUMNA_VARIABLES'] == 'DIV_SHANNON' , 'DISIDAD DE SHANNON' , df_muestreo_regular_copy['COLUMNA_VARIABLES'])
        df_muestreo_regular_copy['COLUMNA_VARIABLES'] = np.where(df_muestreo_regular_copy['COLUMNA_VARIABLES'] == 'BIOM_TOTAL' , 'BIOMASA TOTAL' , df_muestreo_regular_copy['COLUMNA_VARIABLES'])
        df_muestreo_regular_copy['COLUMNA_VARIABLES'] = np.where(df_muestreo_regular_copy['COLUMNA_VARIABLES'] == 'UNIF_PIELOU' , 'UNIFORMIDAD DE PIELOU' , df_muestreo_regular_copy['COLUMNA_VARIABLES'])
        df_muestreo_regular_copy['COLUMNA_VARIABLES'] = np.where(df_muestreo_regular_copy['COLUMNA_VARIABLES'] == 'CLASIF_PERTURB' , 'CLASIFICACIÓN DE PERTURBACIÓN' , df_muestreo_regular_copy['COLUMNA_VARIABLES'])
        df_muestreo_regular_copy['COLUMNA_VARIABLES'] = np.where(df_muestreo_regular_copy['COLUMNA_VARIABLES'] == 'N°_TAXA' , 'NUMERO DE TAXA' , df_muestreo_regular_copy['COLUMNA_VARIABLES'])
        df_muestreo_regular_copy['COLUMNA_VARIABLES'] = np.where(df_muestreo_regular_copy['COLUMNA_VARIABLES'] == 'ABUNDANCIA' , 'ABUNDANCIA TOTAL' , df_muestreo_regular_copy['COLUMNA_VARIABLES'])

      
        # Eliminamos las columnas innecesarias del archivo

        df_muestreo_regular_copy = df_muestreo_regular_copy[['ID', 'NOMB_PROY', 'COD_PROY', 'ETAP_PROY', 'JEFE_PROY', 'INST_PROY',
       'NOM_SECTOR', 'COD_REG', 'VARIABLE', 'FECHA_INI', 'FECHA_TER','HORA_INI', 'FECHA_INICIO', 'N_ESTACION', 'LATITUD', 'LONGITUD',  'PROF_SECT', 'COLUMNA_VARIABLES', 'VALOR']]
        
        

        df_muestreo_regular_copy['FECHA_INICIO'] = df_muestreo_regular_copy['FECHA_INICIO'].dt.strftime('%d/%m/%Y %H:%M:%S')


        df_muestreo_regular_copy['ORIGEN'] = 'BD_MuestreoRegular_SEGUIMIENTO_2019'



        return df_muestreo_regular_copy , columnas_fijas , columnas_variables


    except Exception as e:
        print(f"Ocurrió un error en la función limpieza_muestreo_regular: {e}")
        ex = sys.exc_info()[2]
        print("Error en el archivo : " + str(ex.tb_frame) + " En la linea : " + str(ex.tb_lineno))

# %%
df_muestreo_regular_copy , columnas_fijas , columnas_variables = limpieza_muestreo_regular(df_muestreo_regular)

# %%
df_muestreo_regular_copy['FECHA_INICIO'].unique()
# Out:
# array(['11/04/2019 00:00:00', '11/04/2019 23:45:36',
#        '15/04/2019 00:00:00', '24/07/2019 23:45:36',
#        '26/07/2019 00:00:00', '10/05/2019 15:55:00',
#        '10/05/2019 16:40:00', '10/05/2019 14:55:00',
#        '10/05/2019 12:55:00', '10/05/2019 11:18:00',
#        '10/05/2019 12:20:00', '10/05/2019 10:25:00',
#        '10/05/2019 09:55:00', '10/05/2019 09:02:00',
#        '10/05/2019 08:15:00', '12/05/2019 15:40:00',
#        '12/05/2019 00:00:00', '30/05/2019 11:00:00',
#        '09/05/2019 00:00:00', '12/05/2019 14:30:00',
#        '30/05/2019 00:00:00', '30/05/2019 13:15:00',
#        '02/06/2019 00:00:00', '30/05/2019 15:00:00',
#        '30/05/2019 16:20:00', '02/06/2019 16:46:00',
#        '02/06/2019 16:00:00', '02/06/2019 15:18:00',
#        '06/06/2019 23:45:36', '03/06/2019 23:45:36',
#        '03/06/2019 09:20:00', '03/06/2019 08:35:00',
#        '08/06/2019 08:11:00', '08/06/2019 08:45:00',
#        '06/06/2019 00:00:00', '06/06/2019 17:26:00',
#        '06/06/2019 17:00:00', '07/06/2019 13:42:00',
#        '07/06/2019 12:22:00', '07/06/2019 00:00:00',
#        '07/06/2019 11:00:00', '07/06/2019 16:00:00',
#        '07/06/2019 17:56:00', '15/05/2019 00:00:00',
#        '09/06/2019 16:56:00', '09/06/2019 17:49:00',
#        '09/06/2019 18:24:00', '09/06/2019 16:02:00',
#        '09/06/2019 15:10:00', '09/06/2019 13:09:00',
#        '09/06/2019 12:40:00', '09/06/2019 11:59:00',
#        '09/06/2019 11:00:00', '09/06/2019 09:09:00',
#        '09/06/2019 10:10:00', '08/06/2019 14:10:00',
#        '13/05/2019 00:00:00', '14/05/2019 00:00:00',
#        '16/05/2019 00:00:00', '20/05/2019 00:00:00',
#        '19/05/2019 00:00:00', '18/05/2019 00:00:00',
#        '14/06/2019 15:12:00', '14/06/2019 13:40:00',
#        '14/06/2019 11:34:00', '14/06/2019 10:10:00',
#        '14/06/2019 08:50:00', '13/06/2019 09:54:00',
#        '13/06/2019 08:55:00', '13/06/2019 10:53:00',
#        '13/06/2019 00:00:00', '13/06/2019 15:50:00',
#        '15/06/2019 17:17:00', '15/06/2019 16:20:00',
#        '15/06/2019 14:55:00', '15/06/2019 09:55:00',
#        '15/06/2019 09:00:00', '14/06/2019 17:22:00',
#        '14/06/2019 16:20:00', '13/06/2019 14:00:00',
#        '25/06/2019 16:02:00', '24/06/2019 10:30:00',
#        '25/06/2019 11:45:00', '25/06/2019 09:06:00',
#        '25/06/2019 08:25:00', '24/06/2019 15:17:00',
#        '24/06/2019 14:05:00', '18/06/2019 10:38:00',
#        '18/06/2019 13:15:00', '17/06/2019 15:52:00',
#        '17/06/2019 11:55:00', '17/06/2019 08:55:00',
#        '19/06/2019 14:50:00', '19/06/2019 15:39:00',
#        '20/06/2019 08:44:00', '21/06/2019 14:01:00',
#        '21/06/2019 15:00:00', '16/06/2019 15:20:00',
#        '16/06/2019 13:30:00', '16/06/2019 11:55:00',
#        '16/06/2019 10:20:00', '23/06/2019 11:00:00',
#        '10/08/2019 15:24:00', '10/08/2019 16:19:00',
#        '11/08/2019 22:45:00', '11/08/2019 12:49:00',
#        '11/08/2019 15:43:00', '11/08/2019 17:58:00',
#        '11/08/2019 18:40:00', '11/08/2019 10:16:00'], dtype=object)

# %%
df_comau_ph_copy['FECHA_INICIO'].unique()
# Out:
# array(['18/12/2019 17:05:00', '18/12/2019 18:36:00', nan,
#        '18/12/2019 16:09:00', '18/12/2019 14:49:00',
#        '18/12/2019 10:00:00', '18/12/2019 10:35:00',
#        '18/12/2019 12:13:00', '17/12/2019 09:40:00',
#        '17/12/2019 11:23:00', '16/12/2019 18:30:00',
#        '16/12/2019 17:33:00', '16/12/2019 17:09:00',
#        '16/12/2019 11:57:00', '16/12/2019 11:33:00',
#        '16/12/2019 09:10:00', '15/12/2019 16:38:00',
#        '15/12/2019 18:05:00', '17/12/2019 13:47:00',
#        '17/12/2019 14:20:00', '17/12/2019 16:15:00',
#        '04/02/2020 09:10:00', '04/02/2020 09:37:00',
#        '03/02/2020 16:58:00', '03/02/2020 17:32:00',
#        '03/02/2020 14:31:00', '03/02/2020 15:05:00',
#        '03/02/2020 15:54:00', '02/02/2020 13:47:00',
#        '02/02/2020 14:43:00', '02/02/2020 10:04:00',
#        '02/02/2020 09:24:00', '02/02/2020 08:29:00',
#        '01/02/2020 12:47:00', '01/02/2020 08:20:00',
#        '31/01/2020 19:09:00', '31/01/2020 15:47:00',
#        '31/01/2020 17:51:00', '02/02/2020 15:14:00',
#        '02/02/2020 16:44:00', '02/02/2020 18:50:00',
#        '26/02/2020 08:59:00', '26/02/2020 09:47:00',
#        '25/02/2020 09:53:00', '25/02/2020 11:59:00',
#        '21/02/2020 09:31:00', '21/02/2020 12:12:00',
#        '22/02/2020 18:00:00', '20/02/2020 18:24:00',
#        '20/02/2020 11:20:00', '20/02/2020 10:12:00',
#        '20/02/2020 08:48:00', '20/02/2020 14:53:00',
#        '19/02/2020 16:52:00', '19/02/2020 14:39:00',
#        '19/02/2020 08:11:00', '19/02/2020 11:03:00',
#        '22/02/2020 14:58:00', '22/02/2020 11:06:00',
#        '22/02/2020 09:58:00'], dtype=object)

# %%
df_ph_copy.columns
# Out:
# Index(['ID', 'NOMB_PROY', 'COD_PROY', 'ETAP_PROY', 'JEFE_PROY', 'INST_PROY',
#        'NOM_SECTOR', 'COD_REG', 'FECHA_INI', 'FECHA_TER', 'HORA_INI',
#        'N_ESTACION', 'LATITUD', 'LONGITUD', 'PROF_SECT', 'COLUMNA_VARIABLES',
#        'VALOR', 'FECHA_INICIO', 'ORIGEN'],
#       dtype='object')

# %%
# Realizamos la union entre los 3 dataframes 

df_muestreo_regular_merge = pd.concat([df_muestreo_regular_copy , df_comau_ph_copy ,df_ph_copy ] , ignore_index= True)

# Modificamos la columna NOMB_PROY 

df_muestreo_regular_merge['NOMB_PROY'] = 'ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO 2019-2020'

# Cambiamos el COD_PROY

df_muestreo_regular_merge['COD_PROY'] = '656-115'


# Cambiamos los 'FIORDO COMAU', 'FIORDO COMPU'

df_muestreo_regular_merge['NOM_SECTOR'] = np.where(df_muestreo_regular_merge['NOM_SECTOR'] == 'FIORDO COMAU' , 'Fiordo Comau', df_muestreo_regular_merge['NOM_SECTOR'])
df_muestreo_regular_merge['NOM_SECTOR'] = np.where(df_muestreo_regular_merge['NOM_SECTOR'] == 'FIORDO COMPU' , 'Fiordo Compu', df_muestreo_regular_merge['NOM_SECTOR'])

# %%
df_muestreo_regular_merge['FECHA_INICIO'].unique()
# Out:
# array(['11/04/2019 00:00:00', '11/04/2019 23:45:36',
#        '15/04/2019 00:00:00', '24/07/2019 23:45:36',
#        '26/07/2019 00:00:00', '10/05/2019 15:55:00',
#        '10/05/2019 16:40:00', '10/05/2019 14:55:00',
#        '10/05/2019 12:55:00', '10/05/2019 11:18:00',
#        '10/05/2019 12:20:00', '10/05/2019 10:25:00',
#        '10/05/2019 09:55:00', '10/05/2019 09:02:00',
#        '10/05/2019 08:15:00', '12/05/2019 15:40:00',
#        '12/05/2019 00:00:00', '30/05/2019 11:00:00',
#        '09/05/2019 00:00:00', '12/05/2019 14:30:00',
#        '30/05/2019 00:00:00', '30/05/2019 13:15:00',
#        '02/06/2019 00:00:00', '30/05/2019 15:00:00',
#        '30/05/2019 16:20:00', '02/06/2019 16:46:00',
#        '02/06/2019 16:00:00', '02/06/2019 15:18:00',
#        '06/06/2019 23:45:36', '03/06/2019 23:45:36',
#        '03/06/2019 09:20:00', '03/06/2019 08:35:00',
#        '08/06/2019 08:11:00', '08/06/2019 08:45:00',
#        '06/06/2019 00:00:00', '06/06/2019 17:26:00',
#        '06/06/2019 17:00:00', '07/06/2019 13:42:00',
#        '07/06/2019 12:22:00', '07/06/2019 00:00:00',
#        '07/06/2019 11:00:00', '07/06/2019 16:00:00',
#        '07/06/2019 17:56:00', '15/05/2019 00:00:00',
#        '09/06/2019 16:56:00', '09/06/2019 17:49:00',
#        '09/06/2019 18:24:00', '09/06/2019 16:02:00',
#        '09/06/2019 15:10:00', '09/06/2019 13:09:00',
#        '09/06/2019 12:40:00', '09/06/2019 11:59:00',
#        '09/06/2019 11:00:00', '09/06/2019 09:09:00',
#        '09/06/2019 10:10:00', '08/06/2019 14:10:00',
#        '13/05/2019 00:00:00', '14/05/2019 00:00:00',
#        '16/05/2019 00:00:00', '20/05/2019 00:00:00',
#        '19/05/2019 00:00:00', '18/05/2019 00:00:00',
#        '14/06/2019 15:12:00', '14/06/2019 13:40:00',
#        '14/06/2019 11:34:00', '14/06/2019 10:10:00',
#        '14/06/2019 08:50:00', '13/06/2019 09:54:00',
#        '13/06/2019 08:55:00', '13/06/2019 10:53:00',
#        '13/06/2019 00:00:00', '13/06/2019 15:50:00',
#        '15/06/2019 17:17:00', '15/06/2019 16:20:00',
#        '15/06/2019 14:55:00', '15/06/2019 09:55:00',
#        '15/06/2019 09:00:00', '14/06/2019 17:22:00',
#        '14/06/2019 16:20:00', '13/06/2019 14:00:00',
#        '25/06/2019 16:02:00', '24/06/2019 10:30:00',
#        '25/06/2019 11:45:00', '25/06/2019 09:06:00',
#        '25/06/2019 08:25:00', '24/06/2019 15:17:00',
#        '24/06/2019 14:05:00', '18/06/2019 10:38:00',
#        '18/06/2019 13:15:00', '17/06/2019 15:52:00',
#        '17/06/2019 11:55:00', '17/06/2019 08:55:00',
#        '19/06/2019 14:50:00', '19/06/2019 15:39:00',
#        '20/06/2019 08:44:00', '21/06/2019 14:01:00',
#        '21/06/2019 15:00:00', '16/06/2019 15:20:00',
#        '16/06/2019 13:30:00', '16/06/2019 11:55:00',
#        '16/06/2019 10:20:00', '23/06/2019 11:00:00',
#        '10/08/2019 15:24:00', '10/08/2019 16:19:00',
#        '11/08/2019 22:45:00', '11/08/2019 12:49:00',
#        '11/08/2019 15:43:00', '11/08/2019 17:58:00',
#        '11/08/2019 18:40:00', '11/08/2019 10:16:00',
#        '18/12/2019 17:05:00', '18/12/2019 18:36:00', nan,
#        '18/12/2019 16:09:00', '18/12/2019 14:49:00',
#        '18/12/2019 10:00:00', '18/12/2019 10:35:00',
#        '18/12/2019 12:13:00', '17/12/2019 09:40:00',
#        '17/12/2019 11:23:00', '16/12/2019 18:30:00',
#        '16/12/2019 17:33:00', '16/12/2019 17:09:00',
#        '16/12/2019 11:57:00', '16/12/2019 11:33:00',
#        '16/12/2019 09:10:00', '15/12/2019 16:38:00',
#        '15/12/2019 18:05:00', '17/12/2019 13:47:00',
#        '17/12/2019 14:20:00', '17/12/2019 16:15:00',
#        '04/02/2020 09:10:00', '04/02/2020 09:37:00',
#        '03/02/2020 16:58:00', '03/02/2020 17:32:00',
#        '03/02/2020 14:31:00', '03/02/2020 15:05:00',
#        '03/02/2020 15:54:00', '02/02/2020 13:47:00',
#        '02/02/2020 14:43:00', '02/02/2020 10:04:00',
#        '02/02/2020 09:24:00', '02/02/2020 08:29:00',
#        '01/02/2020 12:47:00', '01/02/2020 08:20:00',
#        '31/01/2020 19:09:00', '31/01/2020 15:47:00',
#        '31/01/2020 17:51:00', '02/02/2020 15:14:00',
#        '02/02/2020 16:44:00', '02/02/2020 18:50:00',
#        '26/02/2020 08:59:00', '26/02/2020 09:47:00',
#        '25/02/2020 09:53:00', '25/02/2020 11:59:00',
#        '21/02/2020 09:31:00', '21/02/2020 12:12:00',
#        '22/02/2020 18:00:00', '20/02/2020 18:24:00',
#        '20/02/2020 11:20:00', '20/02/2020 10:12:00',
#        '20/02/2020 08:48:00', '20/02/2020 14:53:00',
#        '19/02/2020 16:52:00', '19/02/2020 14:39:00',
#        '19/02/2020 08:11:00', '19/02/2020 11:03:00',
#        '22/02/2020 14:58:00', '22/02/2020 11:06:00',
#        '22/02/2020 09:58:00', Timestamp('2019-09-13 19:07:00'),
#        Timestamp('2019-09-13 19:26:00'), Timestamp('2019-09-13 19:36:00'),
#        Timestamp('2019-09-13 18:09:00'), Timestamp('2019-09-13 18:29:00'),
#        Timestamp('2019-09-13 18:51:00'), Timestamp('2019-09-13 17:50:00'),
#        Timestamp('2019-09-13 16:52:00'), Timestamp('2019-09-13 16:57:00'),
#        Timestamp('2019-09-13 16:40:00'), Timestamp('2019-09-13 21:55:00'),
#        Timestamp('2019-09-13 21:50:00'), Timestamp('2019-09-13 21:30:00'),
#        Timestamp('2019-09-13 14:45:00'), Timestamp('2019-09-13 18:57:00'),
#        Timestamp('2019-11-08 00:00:00'), Timestamp('2019-11-07 00:00:00'),
#        Timestamp('2020-02-06 09:54:00'), Timestamp('2020-02-06 10:08:00'),
#        Timestamp('2020-02-06 10:39:00'), Timestamp('2020-02-06 10:54:00'),
#        Timestamp('2020-02-06 11:20:00'), Timestamp('2020-02-06 11:35:00'),
#        Timestamp('2020-02-06 12:16:00'), Timestamp('2020-02-06 12:43:00'),
#        Timestamp('2020-02-06 13:02:00'), Timestamp('2020-02-06 13:40:00'),
#        Timestamp('2020-02-06 15:24:00'), Timestamp('2020-02-05 19:14:00'),
#        Timestamp('2020-02-06 15:40:00'), Timestamp('2020-02-06 16:15:00'),
#        Timestamp('2020-02-05 19:38:00'), Timestamp('2020-02-05 17:31:00'),
#        Timestamp('2020-02-05 18:37:00'), Timestamp('2020-02-06 09:33:00'),
#        Timestamp('2020-02-05 10:45:00'), Timestamp('2020-02-05 14:31:00')],
#       dtype=object)

# %%
df_muestreo_regular_merge.columns
# Out:
# Index(['ID', 'NOMB_PROY', 'COD_PROY', 'ETAP_PROY', 'JEFE_PROY', 'INST_PROY',
#        'NOM_SECTOR', 'COD_REG', 'VARIABLE', 'FECHA_INI', 'FECHA_TER',
#        'HORA_INI', 'FECHA_INICIO', 'N_ESTACION', 'LATITUD', 'LONGITUD',
#        'PROF_SECT', 'COLUMNA_VARIABLES', 'VALOR', 'ORIGEN'],
#       dtype='object')

# %%
df_muestreo_regular_merge['FECHA_INI'].unique()
# Out:
# array([Timestamp('2019-04-11 00:00:00'), Timestamp('2019-04-15 00:00:00'),
#        Timestamp('2019-07-24 00:00:00'), Timestamp('2019-07-26 00:00:00'),
#        Timestamp('2019-05-10 00:00:00'), Timestamp('2019-05-12 00:00:00'),
#        Timestamp('2019-05-30 00:00:00'), Timestamp('2019-05-09 00:00:00'),
#        Timestamp('2019-06-02 00:00:00'), Timestamp('2019-06-06 00:00:00'),
#        Timestamp('2019-06-03 00:00:00'), Timestamp('2019-06-08 00:00:00'),
#        Timestamp('2019-06-07 00:00:00'), Timestamp('2019-05-15 00:00:00'),
#        Timestamp('2019-06-09 00:00:00'), Timestamp('2019-05-13 00:00:00'),
#        Timestamp('2019-05-14 00:00:00'), Timestamp('2019-05-16 00:00:00'),
#        Timestamp('2019-05-20 00:00:00'), Timestamp('2019-05-19 00:00:00'),
#        Timestamp('2019-05-18 00:00:00'), Timestamp('2019-06-14 00:00:00'),
#        Timestamp('2019-06-13 00:00:00'), Timestamp('2019-06-15 00:00:00'),
#        Timestamp('2019-06-25 00:00:00'), Timestamp('2019-06-24 00:00:00'),
#        Timestamp('2019-06-18 00:00:00'), Timestamp('2019-06-17 00:00:00'),
#        Timestamp('2019-06-19 00:00:00'), Timestamp('2019-06-20 00:00:00'),
#        Timestamp('2019-06-21 00:00:00'), Timestamp('2019-06-16 00:00:00'),
#        Timestamp('2019-06-23 00:00:00'), Timestamp('2019-08-10 00:00:00'),
#        Timestamp('2019-08-11 00:00:00'), Timestamp('2019-12-18 00:00:00'),
#        NaT, Timestamp('2019-12-17 00:00:00'),
#        Timestamp('2019-12-16 00:00:00'), Timestamp('2019-12-15 00:00:00'),
#        Timestamp('2020-02-04 00:00:00'), Timestamp('2020-02-03 00:00:00'),
#        Timestamp('2020-02-02 00:00:00'), Timestamp('2020-02-01 00:00:00'),
#        Timestamp('2020-01-31 00:00:00'), Timestamp('2020-02-26 00:00:00'),
#        Timestamp('2020-02-25 00:00:00'), Timestamp('2020-02-21 00:00:00'),
#        Timestamp('2020-02-22 00:00:00'), Timestamp('2020-02-20 00:00:00'),
#        Timestamp('2020-02-19 00:00:00'), '2019-09-13', '2019-11-08',
#        '2019-11-07', '2020-02-06', '2020-02-05'], dtype=object)

# %%
df_muestreo_regular_merge['NOM_SECTOR'].unique()
# Out:
# array(['Atacama', 'Coquimbo', 'Bio-Bio', 'Valdivia', 'Estuario',
#        'Reloncavi', 'Calbuco', 'Chacao', 'Butachauques', 'Chaulinec',
#        'Tenaun', 'Chiloe central', 'Desertores', 'Quellon', 'Hornopiren',
#        'Ayacara', 'Chaiten', 'Guaitecas', 'Moraleda', 'Puyuhuapi',
#        'Aysen', 'Natales', 'Fiordo Comau', 'Fiordo Compu'], dtype=object)

# %%
df_muestreo_regular_merge.to_csv('output/2019/AMBIENTALES_MUESTREO_REGULAR_2019.csv' , index=False)

# %% [markdown]
# # Limpieza BD fisicos y quimicos Maullín (En espera)
#
# Este archivo contiene varias hojas , hay que almacenar todo dentro de un solo archivo o hay que separarlo.

# %%
df_fq = pd.read_excel(r'C:\Users\felipe.abarzua\Desktop\DATA_AMBIENTALES\Proyecto Seguimiento Ambiental\2019_P656115\8_BD_fisicos_y_qcos_Maullín.xlsx' , sheet_name= 'Maullin columna de agua')

# %%
def limpieza_fisicos_quimicos(df):

    try:
        
        #Eliminamos las filas innecesarias
        df = df.iloc[12: , :]

        #Creamos una copia del dataset
        df_fq_copy = df.copy()

        #Reiniciamos los index
        df_fq_copy = df_fq_copy.reset_index(drop = True)

        #Dejamos la primera fila como columna 
        df_fq_copy.columns = df_fq_copy.iloc[0]

        #Eliminamos la primera fila 
        df_fq_copy = df_fq_copy.iloc[1: , :]

        #Reiniciamos los index
        df_fq_copy = df_fq_copy.reset_index(drop = True)


        #Creamos una columna de ID 
        df_fq_copy.insert(0 , 'ID' , df_fq_copy.index + 1 )

        #Remplazamos los nombres de las columnas
        df_fq_copy = df_fq_copy.rename(columns = {'CLOROF_ a ' : 'CLOROF_A' , 'LONGUITUD' : 'LONGITUD'})


        #Creamos las listas de columnas 
        columnas = df_fq_copy.columns.to_list()

        #Creamos las columnas fijas para transformar los equipos
        columnas_equipos = [columnas[8] , columnas[13] , columnas[16] , columnas[19] , columnas[22]]

        #Creamos las columnas de Prof_Equipos

        columnas_prof = [columnas[9] , columnas[14] , columnas[17] , columnas[20] , columnas[23]]

        #Creamos las columnas fijas para convertir las columnas de equipos

        columnas_fijas = []

        for columna in columnas:

            if columna not in columnas_equipos:

                columnas_fijas.append(columna)


        #Realizamos un melt para convertir las columnas de equipos a filas 

        df_fq_copy = pd.melt(df_fq_copy , id_vars = columnas_fijas , value_vars= columnas_equipos , var_name= 'COL_EQUIPO' , value_name= 'EQUIPO')

        #Eliminamos la columna de COL_EQUIPO

        df_fq_copy = df_fq_copy[['ID', 'NOMB_PROY', 'COD_PROY', 'FECHA_INI', 'FECHA_TER', 'LATITUD', 'LONGITUD', 'ESTACION', 'PROF_EQU_1', 'PROF_SEC', 'TEMPERATURA', 'Ph', 'PROF_EQU_2', 'SALINIDAD', 'PROF_EQU_3', 'OXIGE_DIS ', 'PROF_EQU_4',
                                'TRANSPAREN', 'PROF_EQU_5', 'LUZ_PAR', 'CLOROF_A', 'CLOROF_ACT',  'FEOPIGM', 'FEOPIGM_%', 'MAT_INORGA', 'MAT_ORGANI', 'NITRATO','FOSFATO', 'SILICATO', 'COD_REG', 'OBSERV', 'SHAPE', 'EQUIPO']]


        #Creamos las listas de columnas 
        columnas = df_fq_copy.columns.to_list()

        #Volvemos a crear la lista de columnas fijas pero para convertir las columnas de profundidad

        columnas_fijas = []

        for columna in columnas:

            if columna not in columnas_prof:

                columnas_fijas.append(columna)


        
        #Realizamos un melt para convertir las columnas de profundidad_equip a filas

        df_fq_copy = pd.melt(df_fq_copy , id_vars = columnas_fijas , value_vars= columnas_prof , var_name= 'COL_Pof' , value_name= 'PROF_EQUIP')


        #Eliminamos la columna COL_Prof

        df_fq_copy = df_fq_copy[['ID', 'NOMB_PROY', 'COD_PROY', 'FECHA_INI', 'FECHA_TER', 'LATITUD',
       'LONGITUD', 'ESTACION', 'PROF_SEC', 'TEMPERATURA', 'Ph', 'SALINIDAD','OXIGE_DIS ', 'TRANSPAREN', 'LUZ_PAR', 'CLOROF_A', 'CLOROF_ACT',
       'FEOPIGM', 'FEOPIGM_%', 'MAT_INORGA', 'MAT_ORGANI', 'NITRATO','FOSFATO', 'SILICATO', 'COD_REG', 'OBSERV', 'SHAPE', 'EQUIPO',
        'PROF_EQUIP']]


        return df_fq_copy , columnas , columnas_equipos , columnas_fijas , columnas_prof


    except Exception as e:
        print(f"Ocurrió un error en la función limpieza_muestreo_regular: {e}")
        ex = sys.exc_info()[2]
        print("Error en el archivo : " + str(ex.tb_frame) + " En la linea : " + str(ex.tb_lineno))

# %%
df_fq_copy , columnas , columnas_equipos ,  columnas_fijas , columnas_prof= limpieza_fisicos_quimicos(df_fq)

# %%
df_fq_copy
# Out:
#       ID                                          NOMB_PROY COD_PROY  \
# 0      1  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 1      2  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 2      3  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 3      4  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 4      5  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# ...   ..                                                ...      ...
# 1195  44  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 1196  45  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 1197  46  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 1198  47  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
# 1199  48  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...  656-115
#
#       FECHA_INI  FECHA_TER    LATITUD   LONGITUD ESTACION PROF_SEC  \
# 0    2019-12-05 2019-12-05 -41.585583 -73.646833       E1      0.8
# 1    2019-12-05 2019-12-05  -41.58525  -73.63975       E2      0.7
# 2    2019-12-05 2019-12-05 -41.585722 -73.634722       E3        1
# 3    2019-12-05 2019-12-05  -41.59125 -73.630472       E4      1.2
# 4    2019-12-05 2019-12-05   -41.5995 -73.616083       E5      1.3
# ...         ...        ...        ...        ...      ...      ...
# 1195 2020-05-13 2020-05-13  -41.59125 -73.630472       E4        2
# 1196 2020-05-13 2020-05-13   -41.5995 -73.616083       E5      1.5
# 1197 2020-05-13 2020-05-13 -41.586472 -73.653444       C1        1
# 1198 2020-05-13 2020-05-13 -41.591472 -73.647194       C2        2
# 1199 2020-05-13 2020-05-13 -41.599389 -73.619222       C3      1.5
#
#      TEMPERATURA  ... MAT_INORGA MAT_ORGANI NITRATO FOSFATO SILICATO COD_REG  \
# 0           18.7  ...        NaN        NaN     NaN     NaN      NaN       X
# 1           17.9  ...        NaN        NaN     NaN     NaN      NaN       X
# 2           18.5  ...   0.016786   0.003929    0.21   0.208    20.58       X
# 3           18.7  ...   0.012262   0.003095   0.702   0.312    35.07       X
# 4             19  ...   0.024048   0.006667   0.374   0.105    20.79       X
# ...          ...  ...        ...        ...     ...     ...      ...     ...
# 1195          13  ...   0.011395   0.002093   1.476   0.362    30.23       X
# 1196        13.2  ...   0.009125   0.002125   1.295    0.32    37.52       X
# 1197        13.1  ...    0.00954   0.002529   2.138   0.405    19.98       X
# 1198        13.4  ...   0.012088   0.002088   1.898   0.617    21.69       X
# 1199        13.1  ...   0.008111   0.001889   2.129   0.872    41.84       X
#
#                            OBSERV SHAPE                            EQUIPO  \
# 0     Sin presencia de Alga verde   NaN               Orion 4-Star pH/ISE
# 1     Sin presencia de Alga verde   NaN               Orion 4-Star pH/ISE
# 2     Sin presencia de Alga verde   NaN               Orion 4-Star pH/ISE
# 3     Sin presencia de Alga verde   NaN               Orion 4-Star pH/ISE
# 4     Sin presencia de Alga verde   NaN               Orion 4-Star pH/ISE
# ...                           ...   ...                               ...
# 1195                    SIN ALGAS   NaN  Onset HOBO UA-002-64 Pendant 64K
# 1196  Sin presencia de Alga verde   NaN  Onset HOBO UA-002-64 Pendant 64K
# 1197  Sin presencia de Alga verde   NaN  Onset HOBO UA-002-64 Pendant 64K
# 1198  Sin presencia de Alga verde   NaN  Onset HOBO UA-002-64 Pendant 64K
# 1199  Sin presencia de Alga verde   NaN  Onset HOBO UA-002-64 Pendant 64K
#
#      PROF_EQUIP
# 0          0.01
# 1          0.01
# 2          0.01
# 3          0.01
# 4          0.01
# ...         ...
# 1195          2
# 1196        1.5
# 1197          1
# 1198          2
# 1199        1.5
#
# [1200 rows x 29 columns]
