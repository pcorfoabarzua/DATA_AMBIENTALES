# %% [markdown]
# # Limpieza de datos Ambientales
#
#     MACROFAUNA

# %%
import numpy as np 
import pandas as pd
import re 
import datetime 

df_macrofauna = pd.read_excel(r'C:\Users\felipe.abarzua\Desktop\DATA_AMBIENTALES\Proyecto Seguimiento Ambiental\2016_P656\2_BD_MACROFAUNA_2016.xlsx' , sheet_name = '2016' )

# %%
df_macrofauna
# Out:
#                                   Nombre del Proyecto:  \
# 0                                      Etapa Proyecto:
# 1                                        Jefe Proyecto
# 2                                        Institucion:
# 3                                      Nombre Sector:
# 4                                              Región:
# ..                                                 ...
# 299  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 300  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 301  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 302  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 303  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
#
#     ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO 2016 -2017  \
# 0    Objetivo 1. Actividad 2. Muestreos y Analisis ...
# 1                                         Gastón Vidal
# 2                        INSTITUTO DE FOMENTO PESQUERO
# 3    Atacama (Caldera-Bahia Inglesa), Coquimbo (Ton...
# 4    Región de Atacama, Región de Coquimbo, Región ...
# ..                                                 ...
# 299  Objetivo 1. Actividad 2. Muestreos y Analisis ...
# 300  Objetivo 1. Actividad 2. Muestreos y Analisis ...
# 301  Objetivo 1. Actividad 2. Muestreos y Analisis ...
# 302  Objetivo 1. Actividad 2. Muestreos y Analisis ...
# 303  Objetivo 1. Actividad 2. Muestreos y Analisis ...
#
#        Unnamed: 2                     Unnamed: 3  \
# 0             NaN                            NaN
# 1             NaN                            NaN
# 2             NaN                            NaN
# 3             NaN                            NaN
# 4             NaN                            NaN
# ..            ...                            ...
# 299  GASTÓN VIDAL  INSTITUTO DE FOMENTO PESQUERO
# 300  GASTÓN VIDAL  INSTITUTO DE FOMENTO PESQUERO
# 301  GASTÓN VIDAL  INSTITUTO DE FOMENTO PESQUERO
# 302  GASTÓN VIDAL  INSTITUTO DE FOMENTO PESQUERO
# 303  GASTÓN VIDAL  INSTITUTO DE FOMENTO PESQUERO
#
#                                             Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                                                  NaN        NaN        NaN
# 1                                                  NaN        NaN        NaN
# 2                                                  NaN        NaN        NaN
# 3                                                  NaN        NaN        NaN
# 4                                                  NaN        NaN        NaN
# ..                                                 ...        ...        ...
# 299  Campaña_Inv_Ver_2016.Proy.SeguimientoAmbiental...   Valdivia         12
# 300  Campaña_Inv_Ver_2016.Proy.SeguimientoAmbiental...   Valdivia         13
# 301  Campaña_Inv_Ver_2016.Proy.SeguimientoAmbiental...   Valdivia         14
# 302  Campaña_Inv_Ver_2016.Proy.SeguimientoAmbiental...   Valdivia         15
# 303  Campaña_Inv_Ver_2015.Proy.SeguimientoAmbiental...   Valdivia         15
#
#     Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0          NaN        NaN        NaN  ...         NaN         NaN         NaN
# 1          NaN        NaN        NaN  ...         NaN         NaN         NaN
# 2          NaN        NaN        NaN  ...         NaN         NaN         NaN
# 3          NaN        NaN        NaN  ...         NaN         NaN         NaN
# 4          NaN        NaN        NaN  ...         NaN         NaN         NaN
# ..         ...        ...        ...  ...         ...         ...         ...
# 299       7300        570          7  ...      0.6042      0.5467      0.7149
# 300       3290       1520         14  ...      0.4038      0.3949       0.519
# 301        590        130         10  ...      0.5984      0.5404      0.8561
# 302         50         60          3  ...      0.4771      0.9602           1
# 303        130        340          6  ...      0.4367      0.8285      0.6248
#
#     Unnamed: 17               Unnamed: 18 Unnamed: 19  \
# 0           NaN                       NaN         NaN
# 1           NaN                       NaN         NaN
# 2           NaN                       NaN         NaN
# 3           NaN                       NaN         NaN
# 4           NaN                       NaN         NaN
# ..          ...                       ...         ...
# 299       3.119    Ligeramente perturbado      3.5893
# 300       4.298  Moderadamente perturbado       3.227
# 301       3.088    Ligeramente perturbado      2.3077
# 302        3.75  Moderadamente perturbado           3
# 303       4.269  Moderadamente perturbado       4.368
#
#                   Unnamed: 20          Unnamed: 21 Unnamed: 22 Unnamed: 23
# 0                         NaN                  NaN         NaN         NaN
# 1                         NaN                  NaN         NaN         NaN
# 2                         NaN                  NaN         NaN         NaN
# 3                         NaN                  NaN         NaN         NaN
# 4                         NaN                  NaN         NaN         NaN
# ..                        ...                  ...         ...         ...
# 299  Moderadamente perturbado                  NaN          12    Valdivia
# 300    Ligeramente perturbado                  NaN          13    Valdivia
# 301    Ligeramente perturbado                  NaN          14    Valdivia
# 302    Ligeramente perturbado  2016_308 ESTACIONES          15    Valdivia
# 303  Moderadamente perturbado  2015_308 ESTACIONES          15    Valdivia
#
# [304 rows x 24 columns]

# %% [markdown]
# # Creamos la funcion para poder limpiar la data y dejarla en el formato deseado

# %%
def limpieza_macrofauna(df):

    #Eliminamos las columnas innecesarias 

    df = df.iloc[15: ,  :-3]

    #Realizamos una copia del dataset 
    df_macrofauna_copy = df.copy()

    #Reiniciamos los indices del dataframe 

    df_macrofauna_copy =  df_macrofauna_copy.reset_index()

    #Eliminamos la columna de index 

    df_macrofauna_copy = df_macrofauna_copy.iloc[: , 1:]

    #Luego dejamos la primera fila como columna 

    df_macrofauna_copy.columns = df_macrofauna_copy.iloc[0]

    #Dejamos la primera fila como columnas 
    df_macrofauna_copy.columns = df_macrofauna_copy.iloc[0]

     #Eliminamos la primera fila 
    df_macrofauna_copy =  df_macrofauna_copy.iloc[1: , :]

    # Creamos una lista de las columnas
    columnas = df_macrofauna_copy.columns.tolist()

    # Cambiamos los nombres de las columnas desde la posicion 17 hasta la 20

    columnas[17] = 'AMBI INV'
    columnas[18] = 'CLASIFICACIÓN DE PERTURBACIÓN INV'
    columnas[19] = 'AMBI VER'
    columnas[20] =  'CLASIFICACIÓN DE PERTURBACIÓN VER'

    # Realizamos dos ciclos para modificar las columnas de variables para agregarle INV o VER

    for indice , columna in enumerate(columnas):

        if indice >= 7 and indice < 17:

            print(f"La columna '{columna}' esta en la posicion {indice}")

            if indice % 2 == 0:

                print(f"La columna '{columna} se debe agregar '{columnas[indice - 1]}' y VER para convertirse en  '{columnas[indice - 1]} VER' ")

                columnas[indice] = columnas[indice - 1] + ' VER' 


    for indice , columna in enumerate(columnas):

        if indice >= 7 and indice < 17:

            print(f"La columna '{columna}' esta en la posicion {indice}")

            if indice % 2 != 0:

                print(f"La columna '{columna} se debe agregar INV para convertirse en  '{columnas[indice]} INV ' ")

                columnas[indice] = columnas[indice] + ' INV' 


    
    # Utilizamos expresiones regulares para eliminar los espacios en blanco adicionales
    columnas = [re.sub(r'\s+' , ' ' , columna) for columna in columnas]
    
    #Modificamos los nombres de las columnas del dataframe 
    df_macrofauna_copy.columns = columnas 

    #Eliminamos la primera fila del dataframe 
    df_macrofauna_copy = df_macrofauna_copy.iloc[1: , :]

    #Reiniciamos los indices del dataframe 
    df_macrofauna_copy = df_macrofauna_copy.reset_index()

    #Eliminamos la columna de index creada 
    df_macrofauna_copy = df_macrofauna_copy.iloc[: ,  1:]

    #Agregamos una columna de id 
    df_macrofauna_copy.insert(0 ,  'ID' , df_macrofauna_copy.index + 1)
    
    # Volvemos a crear las columnas
    columnas = df_macrofauna_copy.columns.tolist()

    #Creamos las columnas fijas y las columnas de variables para luego realizar el melt 
    columnas_fijas = columnas[:8]
    columnas_variables = columnas[8:]


    # Realizamos un melt para convertir las columnas de variables 
    df_macrofauna_copy = pd.melt(df_macrofauna_copy ,  id_vars = columnas_fijas , var_name= 'VARIABLE' , value_vars= columnas_variables , value_name = 'VALOR')

    
    # Creamos una funcion para extraer los INV o VER de las Variables 

    def obtener_ultimo_tres(texto):
        if isinstance(texto, str) and len(texto) >= 3:
            return texto[-3:]
        else:
            return None  # O algún otro valor por defecto si la cadena es muy corta o no es string

    # Aplica la función a la columna y crea una nueva columna
    df_macrofauna_copy['ESTACION_DEL_ANIO'] = df_macrofauna_copy['VARIABLE'].apply(obtener_ultimo_tres)

     # Creamos una funcion para eliminar los INV y VER de la columna VAriable 
    def eliminar_inv_ver(texto):

        if isinstance(texto, str):
         texto = texto.replace('INV', '')
         texto = texto.replace('VER', '')
        return texto


    #Aplicamos la funcion para eliminar los INV y VER de la columna VARIABLE
    df_macrofauna_copy['VARIABLE'] = df_macrofauna_copy['VARIABLE'].apply(eliminar_inv_ver)

    #Eliminamos los espacios en blanco al final del texto 
    df_macrofauna_copy['ZONA'] = df_macrofauna_copy['ZONA'].str.rstrip()
    df_macrofauna_copy['VARIABLE'] = df_macrofauna_copy['VARIABLE'].str.rstrip()

    # Volvemos a crear las columnas
    columnas = df_macrofauna_copy.columns.tolist()

    # Creamos una columna de Unidad 
    df_macrofauna_copy.insert(9 , 'UNIDAD' , np.nan)

     #Modificamos la columna UNIDAD 
    df_macrofauna_copy['UNIDAD'] =  np.where(df_macrofauna_copy['VARIABLE'] ==  'ABUNDANCIA TOTAL (ind/m2)' , 'ind/m2' ,  df_macrofauna_copy['UNIDAD']  )
    df_macrofauna_copy['UNIDAD'] =  np.where(df_macrofauna_copy['VARIABLE'] ==  'BIOMASA TOTAL(g/m2)' , 'g/m2' ,  df_macrofauna_copy['UNIDAD']  )

    # Modificamos la columna VARIABLE 
    df_macrofauna_copy['VARIABLE'] =  np.where(df_macrofauna_copy['VARIABLE'] ==  'ABUNDANCIA TOTAL (ind/m2)' , 'ABUNDANCIA TOTAL' ,  df_macrofauna_copy['VARIABLE'] )
    df_macrofauna_copy['VARIABLE'] =  np.where(df_macrofauna_copy['VARIABLE'] ==  'BIOMASA TOTAL(g/m2)' , 'BIOMASA TOTAL' ,  df_macrofauna_copy['VARIABLE'] )

    # Remplazamos los valores sd de la columna valor 

    df_macrofauna_copy['VALOR'] = np.where(df_macrofauna_copy['VALOR'] == 'sd' , np.nan , df_macrofauna_copy['VALOR'])

     #Creamos un diccionario para poder mapear la ZONA con el COD_REGION 

    mapeo_regiones = {'Estuario' : 'X' , 'Reloncavi' : 'X' , 'Calbuco' : 'X' , 'Maullin' : 'X' , 'Ancud' : 'X' , 'Chacao' : 'X' , 'Butachauques' : 'X' , 'Chaulinec' : 'X' , 'Tenaun' : 'X' , 'Chiloe central'  : 'X' ,
                  'Desertores' : 'X' , 'Quellon' : 'X' ,  'Hornopiren' : 'X' , 'Ayacara' : 'X' , 'Chaiten' : 'X' ,  'Guaitecas' : 'XI' , 'Moraleda' : 'XI' , 'Puyuhuapi' : 'XI' , 'Aysen' : 'XI' , 'Coquimbo' : 'IV' , 'Atacama' : 'III' , 'Pto. Natales' : 'XII' , 'Bio-Bio' : 'VIII' , 
                  'Valdivia' : 'XIV'}

    # Creamos la columna de COD_REGION
    df_macrofauna_copy['COD_REGION'] = df_macrofauna_copy['ZONA'].map(mapeo_regiones)

    #Agregamos la columna de Año

    df_macrofauna_copy.insert(1 , 'AÑO' , 2016)

    #Modificamos el NOMB_PROY

    df_macrofauna_copy['NOMB_PROY'] = np.where(df_macrofauna_copy['NOMB_PROY'] == 'ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO 2016 -2017' , 'ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO 2016-2017' , df_macrofauna_copy['NOMB_PROY'])


    return df_macrofauna_copy ,  columnas , columnas_fijas , columnas_variables

# %%
df_macrofauna_copy , columnas , columnas_fijas , columnas_variables = limpieza_macrofauna(df_macrofauna)
# Out:
# La columna 'ABUNDANCIA TOTAL (ind/m2) ' esta en la posicion 7
# La columna 'nan' esta en la posicion 8
# La columna 'nan se debe agregar 'ABUNDANCIA TOTAL (ind/m2) ' y VER para convertirse en  'ABUNDANCIA TOTAL (ind/m2)  VER'
# La columna 'NUMERO DE TAXA' esta en la posicion 9
# La columna 'nan' esta en la posicion 10
# La columna 'nan se debe agregar 'NUMERO DE TAXA' y VER para convertirse en  'NUMERO DE TAXA VER'
# La columna 'BIOMASA TOTAL(g/m2)' esta en la posicion 11
# La columna 'nan' esta en la posicion 12
# La columna 'nan se debe agregar 'BIOMASA TOTAL(g/m2)' y VER para convertirse en  'BIOMASA TOTAL(g/m2) VER'
# La columna 'DIVERSIDAD DE SHANNON' esta en la posicion 13
# La columna 'nan' esta en la posicion 14
# La columna 'nan se debe agregar 'DIVERSIDAD DE SHANNON' y VER para convertirse en  'DIVERSIDAD DE SHANNON VER'
# La columna 'UNIFORMIDAD DE PIELOU' esta en la posicion 15
# La columna 'nan' esta en la posicion 16
# La columna 'nan se debe agregar 'UNIFORMIDAD DE PIELOU' y VER para convertirse en  'UNIFORMIDAD DE PIELOU VER'
# La columna 'ABUNDANCIA TOTAL (ind/m2) ' esta en la posicion 7
# La columna 'ABUNDANCIA TOTAL (ind/m2)  se debe agregar INV para convertirse en  'ABUNDANCIA TOTAL (ind/m2)  INV '
# La columna 'ABUNDANCIA TOTAL (ind/m2)  VER' esta en la posicion 8
# La columna 'NUMERO DE TAXA' esta en la posicion 9
# La columna 'NUMERO DE TAXA se debe agregar INV para convertirse en  'NUMERO DE TAXA INV '
# La columna 'NUMERO DE TAXA VER' esta en la posicion 10
# La columna 'BIOMASA TOTAL(g/m2)' esta en la posicion 11
# La columna 'BIOMASA TOTAL(g/m2) se debe agregar INV para convertirse en  'BIOMASA TOTAL(g/m2) INV '
# La columna 'BIOMASA TOTAL(g/m2) VER' esta en la posicion 12
# La columna 'DIVERSIDAD DE SHANNON' esta en la posicion 13
# La columna 'DIVERSIDAD DE SHANNON se debe agregar INV para convertirse en  'DIVERSIDAD DE SHANNON INV '
# La columna 'DIVERSIDAD DE SHANNON VER' esta en la posicion 14
# La columna 'UNIFORMIDAD DE PIELOU' esta en la posicion 15
# La columna 'UNIFORMIDAD DE PIELOU se debe agregar INV para convertirse en  'UNIFORMIDAD DE PIELOU INV '
# La columna 'UNIFORMIDAD DE PIELOU VER' esta en la posicion 16

# %%
df_macrofauna_copy.columns
# Out:
# Index(['ID', 'AÑO', 'NOMB_PROY', 'ETAP_PROY', 'JEFE_PROY', 'INST_PROY',
#        'CAMPAÑA', 'ZONA', 'ESTACION', 'VARIABLE', 'UNIDAD', 'VALOR',
#        'ESTACION_DEL_ANIO', 'COD_REGION'],
#       dtype='object')

# %%
df_macrofauna_copy['VALOR'].unique()
# Out:
# array([290, 1030, 230, ..., 3.227, 2.3077, 4.368], dtype=object)

# %%
df_macrofauna_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4018 entries, 0 to 4017
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 4018 non-null   int64
#  1   AÑO                4018 non-null   int64
#  2   NOMB_PROY          4018 non-null   object
#  3   ETAP_PROY          4018 non-null   object
#  4   JEFE_PROY          4018 non-null   object
#  5   INST_PROY          4018 non-null   object
#  6   CAMPAÑA            4018 non-null   object
#  7   ZONA               4018 non-null   object
#  8   ESTACION           4018 non-null   object
#  9   VARIABLE           4018 non-null   object
#  10  UNIDAD             4018 non-null   object
#  11  VALOR              3948 non-null   object
#  12  ESTACION_DEL_ANIO  4018 non-null   object
#  13  COD_REGION         4018 non-null   object
# dtypes: int64(2), object(12)
# memory usage: 439.6+ KB

# %%
df_macrofauna_copy
# Out:
#        ID   AÑO                                          NOMB_PROY  \
# 0       1  2016  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 1       2  2016  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 2       3  2016  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 3       4  2016  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 4       5  2016  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# ...   ...   ...                                                ...
# 4013  283  2016  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 4014  284  2016  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 4015  285  2016  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 4016  286  2016  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 4017  287  2016  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
#
#                                               ETAP_PROY     JEFE_PROY  \
# 0     Objetivo 1. Actividad 2. Muestreos y Analisis ...  GASTÓN VIDAL
# 1     Objetivo 1. Actividad 2. Muestreos y Analisis ...  GASTÓN VIDAL
# 2     Objetivo 1. Actividad 2. Muestreos y Analisis ...  GASTÓN VIDAL
# 3     Objetivo 1. Actividad 2. Muestreos y Analisis ...  GASTÓN VIDAL
# 4     Objetivo 1. Actividad 2. Muestreos y Analisis ...  GASTÓN VIDAL
# ...                                                 ...           ...
# 4013  Objetivo 1. Actividad 2. Muestreos y Analisis ...  GASTÓN VIDAL
# 4014  Objetivo 1. Actividad 2. Muestreos y Analisis ...  GASTÓN VIDAL
# 4015  Objetivo 1. Actividad 2. Muestreos y Analisis ...  GASTÓN VIDAL
# 4016  Objetivo 1. Actividad 2. Muestreos y Analisis ...  GASTÓN VIDAL
# 4017  Objetivo 1. Actividad 2. Muestreos y Analisis ...  GASTÓN VIDAL
#
#                           INST_PROY  \
# 0     INSTITUTO DE FOMENTO PESQUERO
# 1     INSTITUTO DE FOMENTO PESQUERO
# 2     INSTITUTO DE FOMENTO PESQUERO
# 3     INSTITUTO DE FOMENTO PESQUERO
# 4     INSTITUTO DE FOMENTO PESQUERO
# ...                             ...
# 4013  INSTITUTO DE FOMENTO PESQUERO
# 4014  INSTITUTO DE FOMENTO PESQUERO
# 4015  INSTITUTO DE FOMENTO PESQUERO
# 4016  INSTITUTO DE FOMENTO PESQUERO
# 4017  INSTITUTO DE FOMENTO PESQUERO
#
#                                                 CAMPAÑA      ZONA ESTACION  \
# 0     Campaña_Inv_Ver_2016.Proy.SeguimientoAmbiental...  Estuario        1
# 1     Campaña_Inv_Ver_2016.Proy.SeguimientoAmbiental...  Estuario        2
# 2     Campaña_Inv_Ver_2016.Proy.SeguimientoAmbiental...  Estuario        3
# 3     Campaña_Inv_Ver_2016.Proy.SeguimientoAmbiental...  Estuario        4
# 4     Campaña_Inv_Ver_2016.Proy.SeguimientoAmbiental...  Estuario        5
# ...                                                 ...       ...      ...
# 4013  Campaña_Inv_Ver_2016.Proy.SeguimientoAmbiental...  Valdivia       12
# 4014  Campaña_Inv_Ver_2016.Proy.SeguimientoAmbiental...  Valdivia       13
# 4015  Campaña_Inv_Ver_2016.Proy.SeguimientoAmbiental...  Valdivia       14
# 4016  Campaña_Inv_Ver_2016.Proy.SeguimientoAmbiental...  Valdivia       15
# 4017  Campaña_Inv_Ver_2015.Proy.SeguimientoAmbiental...  Valdivia       15
#
#                            VARIABLE  UNIDAD                     VALOR  \
# 0                  ABUNDANCIA TOTAL  ind/m2                       290
# 1                  ABUNDANCIA TOTAL  ind/m2                      1030
# 2                  ABUNDANCIA TOTAL  ind/m2                       230
# 3                  ABUNDANCIA TOTAL  ind/m2                      1000
# 4                  ABUNDANCIA TOTAL  ind/m2                       620
# ...                             ...     ...                       ...
# 4013  CLASIFICACIÓN DE PERTURBACIÓN     nan  Moderadamente perturbado
# 4014  CLASIFICACIÓN DE PERTURBACIÓN     nan    Ligeramente perturbado
# 4015  CLASIFICACIÓN DE PERTURBACIÓN     nan    Ligeramente perturbado
# 4016  CLASIFICACIÓN DE PERTURBACIÓN     nan    Ligeramente perturbado
# 4017  CLASIFICACIÓN DE PERTURBACIÓN     nan  Moderadamente perturbado
#
#      ESTACION_DEL_ANIO COD_REGION
# 0                  INV          X
# 1                  INV          X
# 2                  INV          X
# 3                  INV          X
# 4                  INV          X
# ...                ...        ...
# 4013               VER        XIV
# 4014               VER        XIV
# 4015               VER        XIV
# 4016               VER        XIV
# 4017               VER        XIV
#
# [4018 rows x 14 columns]

# %%
df_macrofauna_copy.to_csv("output/2016/AMBIENTALES_MACROFAUNA_2016.csv" , index= False)

# %% [markdown]
# # Limpieza de los datos CTD

# %%
# Lectura de los datos de CTD

df_ctd = pd.read_excel(r'C:\Users\felipe.abarzua\Desktop\DATA_AMBIENTALES\Proyecto Seguimiento Ambiental\2016_P656\3_BD_CTD_2016.xlsx' , sheet_name = '2016')

# %%
df_ctd
# Out:
#                                     Nombre del Proyecto:  \
# 0                                        Etapa Proyecto:
# 1                                          Jefe Proyecto
# 2                                          Institucion:
# 3                                                Región:
# 4                                             Variables:
# ...                                                  ...
# 12953  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
# 12954  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
# 12955  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
# 12956  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
# 12957  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
#
#       ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO, 2016-2017.  \
# 0      Objetivo 1. Actividad 2. Muestreos y Analisis ...
# 1                                           Gastón Vidal
# 2                          INSTITUTO DE FOMENTO PESQUERO
# 3            Región de Los Lagos,  Región de Magallanes.
# 4      Temperatura (°C), oxigeno disuelto (ml/L, mg/L...
# ...                                                  ...
# 12953                      INSTITUTO DE FOMENTO PESQUERO
# 12954                      INSTITUTO DE FOMENTO PESQUERO
# 12955                      INSTITUTO DE FOMENTO PESQUERO
# 12956                      INSTITUTO DE FOMENTO PESQUERO
# 12957                      INSTITUTO DE FOMENTO PESQUERO
#
#              Unnamed: 2 Unnamed: 3    Unnamed: 4    Unnamed: 5 Unnamed: 6  \
# 0                   NaN        NaN           NaN           NaN        NaN
# 1                   NaN        NaN           NaN           NaN        NaN
# 2                   NaN        NaN           NaN           NaN        NaN
# 3                   NaN        NaN           NaN           NaN        NaN
# 4                   NaN        NaN           NaN           NaN        NaN
# ...                 ...        ...           ...           ...        ...
# 12953  Seguimiento_2016    I_NAT 9  72°44'45,6''  51°50'19,6''         20
# 12954  Seguimiento_2016    I_NAT 9  72°44'45,6''  51°50'19,6''         20
# 12955  Seguimiento_2016    I_NAT 9  72°44'45,6''  51°50'19,6''         20
# 12956  Seguimiento_2016    I_NAT 9  72°44'45,6''  51°50'19,6''         20
# 12957  Seguimiento_2016    I_NAT 9  72°44'45,6''  51°50'19,6''         20
#
#       Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 0            NaN        NaN        NaN         NaN         NaN         NaN
# 1            NaN        NaN        NaN         NaN         NaN         NaN
# 2            NaN        NaN        NaN         NaN         NaN         NaN
# 3            NaN        NaN        NaN         NaN         NaN         NaN
# 4            NaN        NaN        NaN         NaN         NaN         NaN
# ...          ...        ...        ...         ...         ...         ...
# 12953          6       2016        108        7.43         NaN        2.38
# 12954          6       2016        109    7.432222         NaN    2.331667
# 12955          6       2016        110    7.440455         NaN    2.293636
# 12956          6       2016        111    7.459048         NaN    2.247381
# 12957          6       2016        112        7.46         NaN       2.235
#
#       Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17
# 0             NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN
# 3             NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...
# 12953   23.109545         NaN       23.51     14.5335         NaN
# 12954   22.650556         NaN   23.511667   14.770526         NaN
# 12955   22.278182         NaN   23.519091     14.9335         NaN
# 12956   21.832857         NaN       23.53      14.969         NaN
# 12957      21.715         NaN       23.53   15.004643         NaN
#
# [12958 rows x 18 columns]

# %%
def limpieza_ctd(df):

    #Eliminamos las filas innecesarias 

    df =  df.iloc[10: , :]

    #Realizamos copia del dataframe
    df_ctd_copy = df.copy()

    #Reiniciamos los index 
    df_ctd_copy =  df_ctd_copy.reset_index()

    #Eliminamos la columna de index 
    df_ctd_copy = df_ctd_copy.iloc[: , 1:]

    #Dejamos la primera fila como columnas 
    df_ctd_copy.columns = df_ctd_copy.iloc[0]

    #Eliminamos la primera fila 
    df_ctd_copy = df_ctd_copy.iloc[2: , :]  

    #Reiniciamos los index 
    df_ctd_copy =  df_ctd_copy.reset_index()

    #Eliminamos la columna de index 
    df_ctd_copy = df_ctd_copy.iloc[: , 1:]

    #Creamos una columna de ID 
    df_ctd_copy.insert(0 , 'ID' , df_ctd_copy.index + 1  )
    
    #Renombramos las columnas
    df_ctd_copy = df_ctd_copy.rename(columns= { 'STATION' : 'ESTACION'  , 'CRUISE'  : 'SEGUIMIENTO' , 'LATITUDE' : 'LATITUD' , 'LONGITUDE' : 'LONGITUD'  ,  'TEMPERATURE_(°C)' : 'TEMPERATURA °C' ,  'OXIGENO_DIS_(ML/L)' : 'OXIGENO_DIS_ML/L ML/L' , 'OXIGENO_DIS_(MG/L)' : 'OXIGENO_DIS_MG/L MG/L' , 'OXIGENO_DIS_(%SAT)' : 'OXIGENO_DIS_SAT %' , 'OXIGENO_DIS_(UMOL/KG)' : 'OXIGENO_DIS_UMOLKG UMOL/KG' , 'SALINITY_(PSU)' : 'SALINIDAD PSU' , 'DENSIDAD_(KG/M3)' : 'DENSIDAD KG/M3' , 'FLUORESCENCIA_(MG/M-3)' : 'FLUORESCENCIA MG/M-3' , 'DEPHT_(M)' : 'PROFUNDIDAD'})

    # Creamos una columna de FECHA en la posicion 9 del dataframe
    df_ctd_copy.insert(10 , 'FECHA' , df_ctd_copy.apply(lambda row: datetime.datetime(row['YEAR'], row['MONTH'], row['DAY']), axis=1) )  

    #Formateamos la FECHA  a DD/MM/YYYY 
    # Formatear la fecha y hora al formato deseado
    df_ctd_copy['FECHA'] = df_ctd_copy['FECHA'].dt.strftime('%d/%m/%Y %H:%M:%S')

    #Creamos una lista con las columnas del dataframe
    columnas = df_ctd_copy.columns.tolist()

    #Obtenemos las columnas fijas y las columnas Variables 
    columnas_fijas = columnas[:12]
    columnas_variables = columnas[12:]

    #Realizamos un melt para convertir las columnas variables en filas
    df_ctd_copy = pd.melt(df_ctd_copy , id_vars= columnas_fijas , var_name= 'VARIABLE' ,  value_vars = columnas_variables , value_name= 'VALOR')

    #Creamos una lista con las columnas del dataframe
    columnas = df_ctd_copy.columns.tolist()

    #Creamos una columna llamada Unidad obteniendo lo que viene despues del espacio en la columna VARIABLE
    df_ctd_copy.insert(13 , 'UNIDAD' , df_ctd_copy['VARIABLE'].str.split(' ', n=1).str[1])

    #Luego eliminamos las Unidades de la columna Variable 
    df_ctd_copy['VARIABLE'] =  df_ctd_copy['VARIABLE'].str.split(' ' , n=1).str[0]

    #Dejamos todas las estaciones en MAYUSCULA
    df_ctd_copy['ESTACION'] =  df_ctd_copy['ESTACION'].str.upper()

    #Reemplazamos los NOMB_PROY 
    df_ctd_copy['NOMB_PROY'] =  np.where(df_ctd_copy['NOMB_PROY'] == 'ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO, 2016-2017' , 'ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO 2016-2017' , df_ctd_copy['NOMB_PROY'])

    #Corregimos los valores de las estaciones 
      # Crear un diccionario de mapeo para tus asignaciones
    # Creamos un diccionario de mapeo de sectores
    
    mapeo_sectores = {
        
            "TEN" :  "Tenaun" ,
            "CHAU" : "Chaulinec" ,
            "CHIC" : "Chiloe central" ,
            "CHAC" : "Chacao" ,
            "QUELL" : "Quellon",
            "BUT" : "Butachauques",
            "ANC" : "Ancud" ,
            "REL" : "Reloncavi" ,
            "CALB" : "Calbuco" ,
            "HORN" : "Hornopiren" , 
            "VALD" : "Valdivia" ,
            "AYA" : "Ayacara" 
    }


    mapeo_regiones = {'Estuario' : 'X' , 'Reloncavi' : 'X' , 'Calbuco' : 'X' , 'Maullin' : 'X' , 'Ancud' : 'X' , 'Chacao' : 'X' , 'Butachauques' : 'X' , 'Chaulinec' : 'X' , 'Tenaun' : 'X' , 'Chiloe central'  : 'X' ,
                  'Desertores' : 'X' , 'Quellon' : 'X' ,  'Hornopiren' : 'X' , 'Ayacara' : 'X' , 'Chaiten' : 'X' ,  'Guaitecas' : 'XI' , 'Moraleda' : 'XI' , 'Puyuhuapi' : 'XI' , 'Aysen' : 'XI' , 'Coquimbo' : 'IV' , 'Atacama' : 'III' , 'Pto. Natales' : 'XII' , 'Bio-Bio' : 'VIII' , 
                  'Valdivia' : 'XIV'}

    # Extraemos los Números de la columna ESTACION para crear una la columna N_ESTACION
    df_ctd_copy['N_ESTACION'] = df_ctd_copy['ESTACION'].str.extract(r'(\d+)')

    #Obtenemos el código utilizando la expresion regular 
    df_ctd_copy['CODIGO_EXTRAIDO'] = df_ctd_copy['ESTACION'].str.extract(r'([A-Z]{3,5})')

    #Luego utilizando el diccionario de mapeo creamos la columna de SECTOR utilizando la funcion map

    df_ctd_copy['SECTOR'] = df_ctd_copy['CODIGO_EXTRAIDO'].map(mapeo_sectores)

    #Utilizamos el diccionario de mapeo de regiones para crear la columna COD_REGION

    df_ctd_copy['COD_REGION'] = df_ctd_copy['SECTOR'].map(mapeo_regiones)

    #Se van a eliminar los registros que están nulos en COD_REGION

    df_ctd_copy = df_ctd_copy.dropna(subset=['COD_REGION'])

    #Cambiamos el tipo de dato de la columna N_ESTACION
    df_ctd_copy['N_ESTACION'] = df_ctd_copy['N_ESTACION'].astype(int)

    return df_ctd_copy

# %%
df_ctd_copy = limpieza_ctd(df_ctd)

# %%
df_ctd_copy['VARIABLE'].unique()
# Out:
# array(['TEMPERATURA', 'OXIGENO_DIS_ML/L', 'OXIGENO_DIS_MG/L',
#        'OXIGENO_DIS_SAT', 'OXIGENO_DIS_UMOLKG', 'SALINIDAD', 'DENSIDAD',
#        'FLUORESCENCIA'], dtype=object)

# %%
df_ctd_copy['COD_REGION'].unique()
# Out:
# array(['X'], dtype=object)

# %%
df_ctd_copy.query("ID == 1")
# Out:
#        ID                                          NOMB_PROY  \
# 0       1  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
# 12946   1  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
# 25892   1  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
# 38838   1  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
# 51784   1  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
# 64730   1  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
# 77676   1  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
# 90622   1  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
#
#                            INST_PROY       SEGUIMIENTO  ESTACION LONGITUD  \
# 0      INSTITUTO DE FOMENTO PESQUERO  Seguimiento_2016  I-CHIC 9 -73.5613
# 12946  INSTITUTO DE FOMENTO PESQUERO  Seguimiento_2016  I-CHIC 9 -73.5613
# 25892  INSTITUTO DE FOMENTO PESQUERO  Seguimiento_2016  I-CHIC 9 -73.5613
# 38838  INSTITUTO DE FOMENTO PESQUERO  Seguimiento_2016  I-CHIC 9 -73.5613
# 51784  INSTITUTO DE FOMENTO PESQUERO  Seguimiento_2016  I-CHIC 9 -73.5613
# 64730  INSTITUTO DE FOMENTO PESQUERO  Seguimiento_2016  I-CHIC 9 -73.5613
# 77676  INSTITUTO DE FOMENTO PESQUERO  Seguimiento_2016  I-CHIC 9 -73.5613
# 90622  INSTITUTO DE FOMENTO PESQUERO  Seguimiento_2016  I-CHIC 9 -73.5613
#
#        LATITUD DAY MONTH  YEAR                FECHA PROFUNDIDAD  \
# 0     -42.3695  10     8  2016  10/08/2016 00:00:00           1
# 12946 -42.3695  10     8  2016  10/08/2016 00:00:00           1
# 25892 -42.3695  10     8  2016  10/08/2016 00:00:00           1
# 38838 -42.3695  10     8  2016  10/08/2016 00:00:00           1
# 51784 -42.3695  10     8  2016  10/08/2016 00:00:00           1
# 64730 -42.3695  10     8  2016  10/08/2016 00:00:00           1
# 77676 -42.3695  10     8  2016  10/08/2016 00:00:00           1
# 90622 -42.3695  10     8  2016  10/08/2016 00:00:00           1
#
#                  VARIABLE   UNIDAD  VALOR  N_ESTACION CODIGO_EXTRAIDO  \
# 0             TEMPERATURA       °C   10.7           9            CHIC
# 12946    OXIGENO_DIS_ML/L     ML/L   5.21           9            CHIC
# 25892    OXIGENO_DIS_MG/L     MG/L    NaN           9            CHIC
# 38838     OXIGENO_DIS_SAT        %    NaN           9            CHIC
# 51784  OXIGENO_DIS_UMOLKG  UMOL/KG    NaN           9            CHIC
# 64730           SALINIDAD      PSU  33.15           9            CHIC
# 77676            DENSIDAD    KG/M3  25.39           9            CHIC
# 90622       FLUORESCENCIA   MG/M-3   0.39           9            CHIC
#
#                SECTOR COD_REGION
# 0      Chiloe central          X
# 12946  Chiloe central          X
# 25892  Chiloe central          X
# 38838  Chiloe central          X
# 51784  Chiloe central          X
# 64730  Chiloe central          X
# 77676  Chiloe central          X
# 90622  Chiloe central          X

# %%
df_ctd_copy.to_csv("output/2016/AMBIENTALES_CTD_2016.csv" , index=False)
