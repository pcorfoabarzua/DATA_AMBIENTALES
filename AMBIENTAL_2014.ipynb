# %% [markdown]
# # Limpieza de Ambiental 2014
#
#     MACROFAUNA

# %%
import numpy as np 
import pandas as pd
import re 
import datetime
import traceback as tb
import sys
import math

# Carga del archivo de Ambientales 2014 


# Hay que cambiar la ruta de los archivos cuando se trabaja presencial o remoto

# Presencial C:\Users\felipe.abarzua\Desktop\DATA_AMBIENTALES\
# Remoto  C:\Users\Felipe Abarzúa\Desktop\workspace\DATA_AMBIENTALES\


df_macrofauna = pd.read_excel(r'C:\Users\Felipe Abarzúa\Desktop\workspace\DATA_AMBIENTALES\Proyecto Seguimiento Ambiental\2014_P656\2_BD_MACROFAUNA_2014.xlsx' , sheet_name= '2013')

# %%
df_macrofauna
# Out:
#                                   Nombre del Proyecto:  \
# 0                                      Etapa Proyecto:
# 1                                        Jefe Proyecto
# 2                                        Institucion:
# 3                                      Nombre Sector:
# 4                                              Región:
# ..                                                 ...
# 295  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 296  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 297  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 298  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
# 299  ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICU...
#
#     ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO 2014 -2015  \
# 0    Objetivo 1. Actividad 2. Muestreos y Analisis ...
# 1                                         Gastón Vidal
# 2                        INSTITUTO DE FOMENTO PESQUERO
# 3    Atacama (Caldera-Bahia Inglesa), Coquimbo (Ton...
# 4    Región de Atacama, Región de Coquimbo, Región ...
# ..                                                 ...
# 295  Objetivo 1. Actividad 2. Muestreos y Analisis ...
# 296  Objetivo 1. Actividad 2. Muestreos y Analisis ...
# 297  Objetivo 1. Actividad 2. Muestreos y Analisis ...
# 298  Objetivo 1. Actividad 2. Muestreos y Analisis ...
# 299  Objetivo 1. Actividad 2. Muestreos y Analisis ...
#
#        Unnamed: 2                     Unnamed: 3  \
# 0             NaN                            NaN
# 1             NaN                            NaN
# 2             NaN                            NaN
# 3             NaN                            NaN
# 4             NaN                            NaN
# ..            ...                            ...
# 295  GASTÓN VIDAL  INSTITUTO DE FOMENTO PESQUERO
# 296  GASTÓN VIDAL  INSTITUTO DE FOMENTO PESQUERO
# 297  GASTÓN VIDAL  INSTITUTO DE FOMENTO PESQUERO
# 298  GASTÓN VIDAL  INSTITUTO DE FOMENTO PESQUERO
# 299  GASTÓN VIDAL  INSTITUTO DE FOMENTO PESQUERO
#
#                                             Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                                                  NaN        NaN        NaN
# 1                                                  NaN        NaN        NaN
# 2                                                  NaN        NaN        NaN
# 3                                                  NaN        NaN        NaN
# 4                                                  NaN        NaN        NaN
# ..                                                 ...        ...        ...
# 295  Campaña_Inv_Ver_2014.Proy.SeguimientoAmbiental...    Bio-Bio         16
# 296  Campaña_Inv_Ver_2014.Proy.SeguimientoAmbiental...    Bio-Bio         17
# 297  Campaña_Inv_Ver_2014.Proy.SeguimientoAmbiental...    Bio-Bio         18
# 298  Campaña_Inv_Ver_2014.Proy.SeguimientoAmbiental...    Bio-Bio         19
# 299  Campaña_Inv_Ver_2014.Proy.SeguimientoAmbiental...    Bio-Bio         20
#
#     Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0          NaN        NaN        NaN  ...         NaN         NaN         NaN
# 1          NaN        NaN        NaN  ...         NaN         NaN         NaN
# 2          NaN        NaN        NaN  ...         NaN         NaN         NaN
# 3          NaN        NaN        NaN  ...         NaN         NaN         NaN
# 4          NaN        NaN        NaN  ...         NaN         NaN         NaN
# ..         ...        ...        ...  ...         ...         ...         ...
# 295       1620       3180          9  ...      0.8653      0.6608      0.6894
# 296        600       1990         13  ...       0.873      0.8597       0.809
# 297       5700         80         15  ...       0.391      0.5223      0.8194
# 298       1570      14790          7  ...      0.5621      0.7447      0.4252
# 299        850       4280         14  ...      0.9586      0.7005      0.6428
#
#     Unnamed: 17             Unnamed: 18 Unnamed: 19             Unnamed: 20  \
# 0           NaN                     NaN         NaN                     NaN
# 1           NaN                     NaN         NaN                     NaN
# 2           NaN                     NaN         NaN                     NaN
# 3           NaN                     NaN         NaN                     NaN
# 4           NaN                     NaN         NaN                     NaN
# ..          ...                     ...         ...                     ...
# 295         1.7  Ligeramente perturbado       2.112  Ligeramente perturbado
# 296           2  Ligeramente perturbado       1.553  Ligeramente perturbado
# 297         1.5  Ligeramente perturbado         2.5  Ligeramente perturbado
# 298         2.7  Ligeramente perturbado       1.097           No perturbado
# 299         1.5  Ligeramente perturbado       5.444  Fuertemente perturbado
#
#                  Unnamed: 21 Unnamed: 22 Unnamed: 23
# 0                        NaN         NaN         NaN
# 1                        NaN         NaN         NaN
# 2                        NaN         NaN         NaN
# 3                        NaN         NaN         NaN
# 4                        NaN         NaN         NaN
# ..                       ...         ...         ...
# 295                      NaN          16     Bio-Bio
# 296                      NaN          17     Bio-Bio
# 297                      NaN          18     Bio-Bio
# 298                      NaN          19     Bio-Bio
# 299  293 ESTACIONES AÑO 2014          20     Bio-Bio
#
# [300 rows x 24 columns]

# %%
def limpieza_macrofauna(df):

    #Eliminamos las filas innecesarias 
    df = df.iloc[15: , :-3]

    #Creamos una copia del dataframe
    df_macrofauna_copy = df.copy()

     # Reiniciamos los index
    df_macrofauna_copy =  df_macrofauna_copy.reset_index()

    #Eliminamos la columna index 
    df_macrofauna_copy =  df_macrofauna_copy.iloc[: , 1:]

    #Dejamos la primera fila como columnas 
    df_macrofauna_copy.columns = df_macrofauna_copy.iloc[0]

     #Eliminamos la primera fila 
    df_macrofauna_copy =  df_macrofauna_copy.iloc[1: , :]

    # Creamos una lista de las columnas
    columnas = df_macrofauna_copy.columns.tolist()

    # Cambiamos los nombres de las columnas desde la posicion 17 hasta la 20

    columnas[17] = 'AMBI INV'
    columnas[18] = 'CLASIFICACIÓN DE PERTURBACIÓN INV'
    columnas[19] = 'AMBI VER'
    columnas[20] =  'CLASIFICACIÓN DE PERTURBACIÓN VER'


    # Realizamos dos ciclos para modificar las columnas de variables para agregarle INV o VER

    for indice , columna in enumerate(columnas):

        if indice >= 7 and indice < 17:

            print(f"La columna '{columna}' esta en la posicion {indice}")

            if indice % 2 == 0:

                print(f"La columna '{columna} se debe agregar '{columnas[indice - 1]}' y VER para convertirse en  '{columnas[indice - 1]} VER' ")

                columnas[indice] = columnas[indice - 1] + ' VER' 


    for indice , columna in enumerate(columnas):

        if indice >= 7 and indice < 17:

            print(f"La columna '{columna}' esta en la posicion {indice}")

            if indice % 2 != 0:

                print(f"La columna '{columna} se debe agregar INV para convertirse en  '{columnas[indice]} INV ' ")

                columnas[indice] = columnas[indice] + ' INV' 


    # Utilizamos expresiones regulares para eliminar los espacios en blanco adicionales
    columnas = [re.sub(r'\s+' , ' ' , columna) for columna in columnas]

    #Modificamos los nombres de las columnas del dataframe 
    df_macrofauna_copy.columns = columnas 

    #Eliminamos la primera fila del dataframe 
    df_macrofauna_copy = df_macrofauna_copy.iloc[1: , :]

    #Reiniciamos los indices del dataframe 
    df_macrofauna_copy = df_macrofauna_copy.reset_index()

    #Eliminamos la columna de index creada 
    df_macrofauna_copy = df_macrofauna_copy.iloc[: ,  1:]

    #Agregamos una columna de id 
    df_macrofauna_copy.insert(0 ,  'ID' , df_macrofauna_copy.index + 1)
    
    # Volvemos a crear las columnas
    columnas = df_macrofauna_copy.columns.tolist()

    #Creamos las columnas fijas y las columnas de variables para luego realizar el melt 
    columnas_fijas = columnas[:8]
    columnas_variables = columnas[8:]
    
    # Realizamos un melt para convertir las columnas de variables 
    df_macrofauna_copy = pd.melt(df_macrofauna_copy ,  id_vars = columnas_fijas , var_name= 'VARIABLE' , value_vars= columnas_variables , value_name = 'VALOR')

    
    # Creamos una funcion para extraer los INV o VER de las Variables 

    def obtener_ultimo_tres(texto):
        if isinstance(texto, str) and len(texto) >= 3:
            return texto[-3:]
        else:
            return None  # O algún otro valor por defecto si la cadena es muy corta o no es string

    # Aplica la función a la columna y crea una nueva columna
    df_macrofauna_copy['ESTACION_DEL_ANIO'] = df_macrofauna_copy['VARIABLE'].apply(obtener_ultimo_tres)

    # Creamos una funcion para eliminar los INV y VER de la columna VAriable 
    def eliminar_inv_ver(texto):

        if isinstance(texto, str):
         texto = texto.replace('INV', '')
         texto = texto.replace('VER', '')
        return texto


    #Aplicamos la funcion para eliminar los INV y VER de la columna VARIABLE
    df_macrofauna_copy['VARIABLE'] = df_macrofauna_copy['VARIABLE'].apply(eliminar_inv_ver)

    #Eliminamos los espacios en blanco al final del texto 
    df_macrofauna_copy['ZONA'] = df_macrofauna_copy['ZONA'].str.rstrip()
    df_macrofauna_copy['VARIABLE'] = df_macrofauna_copy['VARIABLE'].str.rstrip()

    # Volvemos a crear las columnas
    columnas = df_macrofauna_copy.columns.tolist()

    # Creamos una columna de Unidad 
    df_macrofauna_copy.insert(9 , 'UNIDAD' , np.nan)

    #Modificamos la columna UNIDAD 
    df_macrofauna_copy['UNIDAD'] =  np.where(df_macrofauna_copy['VARIABLE'] ==  'ABUNDANCIA TOTAL (ind/m2)' , 'ind/m2' ,  df_macrofauna_copy['UNIDAD']  )
    df_macrofauna_copy['UNIDAD'] =  np.where(df_macrofauna_copy['VARIABLE'] ==  'BIOMASA TOTAL(g/m2)' , 'g/m2' ,  df_macrofauna_copy['UNIDAD']  )

    # Modificamos la columna VARIABLE 
    df_macrofauna_copy['VARIABLE'] =  np.where(df_macrofauna_copy['VARIABLE'] ==  'ABUNDANCIA TOTAL (ind/m2)' , 'ABUNDANCIA TOTAL' ,  df_macrofauna_copy['VARIABLE'] )
    df_macrofauna_copy['VARIABLE'] =  np.where(df_macrofauna_copy['VARIABLE'] ==  'BIOMASA TOTAL(g/m2)' , 'BIOMASA TOTAL' ,  df_macrofauna_copy['VARIABLE'] )

    
    #Creamos un diccionario para poder asignar el COD_REGION a la Zona 

    mapeo_regiones = {'Estuario' : 'X' , 'Reloncavi' : 'X' , 'Calbuco' : 'X' , 'Maullin' : 'X' , 'Ancud' : 'X' , 'Chacao' : 'X' , 'Butachauques' : 'X' , 'Chaulinec' : 'X' , 'Tenaun' : 'X' , 'Chiloe central'  : 'X' ,
                  'Desertores' : 'X' , 'Quellon' : 'X' ,  'Hornopiren' : 'X' , 'Ayacara' : 'X' , 'Chaiten' : 'X' ,  'Guaitecas' : 'XI' , 'Moraleda' : 'XI' , 'Puyuhuapi' : 'XI' , 'Aysen' : 'XI' , 'Coquimbo' : 'IV' , 'Atacama' : 'III' , 'Pto. Natales' : 'XII' , 'Bio-Bio' : 'VIII' }


    #Creamos la columna de COD_REGION mapeando la ZONA con el diccionario
    df_macrofauna_copy['COD_REGION'] = df_macrofauna_copy['ZONA'].map(mapeo_regiones)


    # Realizamos un replace de los valores 

    df_macrofauna_copy['NOMB_PROY'] = np.where(df_macrofauna_copy['NOMB_PROY'] == 'ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO 2014 -2015' , 'ESTUDIO SEGUIMIENTO DESEMPEÑO AMBIENTAL ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO 2014-2015' , df_macrofauna_copy['NOMB_PROY'])

    #Agreamos la columna de AÑO
    df_macrofauna_copy.insert(1 , 'AÑO' , 2014)

    
    return df_macrofauna_copy , columnas , columnas_fijas , columnas_variables

# %%
df_macrofauna_copy , columnas , columnas_fijas , columnas_variables  = limpieza_macrofauna(df_macrofauna)
# Out:
# La columna 'ABUNDANCIA TOTAL (ind/m2) ' esta en la posicion 7
# La columna 'nan' esta en la posicion 8
# La columna 'nan se debe agregar 'ABUNDANCIA TOTAL (ind/m2) ' y VER para convertirse en  'ABUNDANCIA TOTAL (ind/m2)  VER'
# La columna 'NUMERO DE TAXA' esta en la posicion 9
# La columna 'nan' esta en la posicion 10
# La columna 'nan se debe agregar 'NUMERO DE TAXA' y VER para convertirse en  'NUMERO DE TAXA VER'
# La columna 'BIOMASA TOTAL(g/m2)' esta en la posicion 11
# La columna 'nan' esta en la posicion 12
# La columna 'nan se debe agregar 'BIOMASA TOTAL(g/m2)' y VER para convertirse en  'BIOMASA TOTAL(g/m2) VER'
# La columna 'DIVERSIDAD DE SHANNON' esta en la posicion 13
# La columna 'nan' esta en la posicion 14
# La columna 'nan se debe agregar 'DIVERSIDAD DE SHANNON' y VER para convertirse en  'DIVERSIDAD DE SHANNON VER'
# La columna 'UNIFORMIDAD DE PIELOU' esta en la posicion 15
# La columna 'nan' esta en la posicion 16
# La columna 'nan se debe agregar 'UNIFORMIDAD DE PIELOU' y VER para convertirse en  'UNIFORMIDAD DE PIELOU VER'
# La columna 'ABUNDANCIA TOTAL (ind/m2) ' esta en la posicion 7
# La columna 'ABUNDANCIA TOTAL (ind/m2)  se debe agregar INV para convertirse en  'ABUNDANCIA TOTAL (ind/m2)  INV '
# La columna 'ABUNDANCIA TOTAL (ind/m2)  VER' esta en la posicion 8
# La columna 'NUMERO DE TAXA' esta en la posicion 9
# La columna 'NUMERO DE TAXA se debe agregar INV para convertirse en  'NUMERO DE TAXA INV '
# La columna 'NUMERO DE TAXA VER' esta en la posicion 10
# La columna 'BIOMASA TOTAL(g/m2)' esta en la posicion 11
# La columna 'BIOMASA TOTAL(g/m2) se debe agregar INV para convertirse en  'BIOMASA TOTAL(g/m2) INV '
# La columna 'BIOMASA TOTAL(g/m2) VER' esta en la posicion 12
# La columna 'DIVERSIDAD DE SHANNON' esta en la posicion 13
# La columna 'DIVERSIDAD DE SHANNON se debe agregar INV para convertirse en  'DIVERSIDAD DE SHANNON INV '
# La columna 'DIVERSIDAD DE SHANNON VER' esta en la posicion 14
# La columna 'UNIFORMIDAD DE PIELOU' esta en la posicion 15
# La columna 'UNIFORMIDAD DE PIELOU se debe agregar INV para convertirse en  'UNIFORMIDAD DE PIELOU INV '
# La columna 'UNIFORMIDAD DE PIELOU VER' esta en la posicion 16

# %%
df_macrofauna_copy['ZONA'].unique()
# Out:
# array(['Estuario', 'Reloncavi', 'Calbuco', 'Maullin', 'Ancud', 'Chacao',
#        'Butachauques', 'Chaulinec', 'Tenaun', 'Chiloe central',
#        'Desertores', 'Quellon', 'Hornopiren', 'Ayacara', 'Chaiten',
#        'Guaitecas', 'Moraleda', 'Puyuhuapi', 'Aysen', 'Coquimbo',
#        'Atacama', 'Pto. Natales', 'Bio-Bio'], dtype=object)

# %%
df_macrofauna_copy.columns
# Out:
# Index(['ID', 'AÑO', 'NOMB_PROY', 'ETAP_PROY', 'JEFE_PROY', 'INST_PROY',
#        'CAMPAÑA', 'ZONA', 'ESTACION', 'VARIABLE', 'UNIDAD', 'VALOR',
#        'ESTACION_DEL_ANIO', 'COD_REGION'],
#       dtype='object')

# %%
df_macrofauna_copy['COD_REGION'].unique()
# Out:
# array(['X', 'XI', 'IV', 'III', 'XII', 'VIII'], dtype=object)

# %%
df_macrofauna_copy.to_csv("output/2014/AMBIENTALES_MACROFAUNA_2014.csv" , index=False)

# %% [markdown]
# # Limpieza de los datos de CTD

# %%
#Cargamos la data 

df_ctd = pd.read_excel(r'C:\Users\felipe.abarzua\Desktop\DATA_AMBIENTALES\Proyecto Seguimiento Ambiental\2014_P656\3_BD_CTD_2014.xlsx' ,  sheet_name= '2014')

# %%
df_ctd
# Out:
#                                    Nombre del Proyecto:  \
# 0                                       Etapa Proyecto:
# 1                                         Jefe Proyecto
# 2                                         Institucion:
# 3                                               Región:
# 4                                            Variables:
# ...                                                 ...
# 4760  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
# 4761  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
# 4762  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
# 4763  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
# 4764  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
#
#      ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO, 2014-2015.  \
# 0     Objetivo 1. Actividad 2. Muestreos y Analisis ...
# 1                                          Gastón Vidal
# 2                         INSTITUTO DE FOMENTO PESQUERO
# 3                                  Región de Los Lagos.
# 4     Temperatura (°C), oxigeno disuelto (ml/L, mg/L...
# ...                                                 ...
# 4760                      INSTITUTO DE FOMENTO PESQUERO
# 4761                      INSTITUTO DE FOMENTO PESQUERO
# 4762                      INSTITUTO DE FOMENTO PESQUERO
# 4763                      INSTITUTO DE FOMENTO PESQUERO
# 4764                      INSTITUTO DE FOMENTO PESQUERO
#
#             Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                  NaN        NaN        NaN        NaN        NaN        NaN
# 1                  NaN        NaN        NaN        NaN        NaN        NaN
# 2                  NaN        NaN        NaN        NaN        NaN        NaN
# 3                  NaN        NaN        NaN        NaN        NaN        NaN
# 4                  NaN        NaN        NaN        NaN        NaN        NaN
# ...                ...        ...        ...        ...        ...        ...
# 4760  Seguimiento_2014   V-ANC 11  -73.88075  -41.79275          8          1
# 4761  Seguimiento_2014   V-ANC 11  -73.88075  -41.79275          8          1
# 4762  Seguimiento_2014   V-ANC 11  -73.88075  -41.79275          8          1
# 4763  Seguimiento_2014   V-ANC 11  -73.88075  -41.79275          8          1
# 4764  Seguimiento_2014   V-ANC 11  -73.88075  -41.79275          8          1
#
#      Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 0           NaN        NaN         NaN         NaN         NaN         NaN
# 1           NaN        NaN         NaN         NaN         NaN         NaN
# 2           NaN        NaN         NaN         NaN         NaN         NaN
# 3           NaN        NaN         NaN         NaN         NaN         NaN
# 4           NaN        NaN         NaN         NaN         NaN         NaN
# ...         ...        ...         ...         ...         ...         ...
# 4760       2014         10       11.87    5.569333    7.953333   90.858667
# 4761       2014         11   11.865625     5.51875      7.8825    90.04375
# 4762       2014         12   11.847143    5.472857       7.815       89.25
# 4763       2014         13   11.825333    5.432667    7.757333   88.568667
# 4764       2014         14       11.82    5.376333       7.678   87.643333
#
#      Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17
# 0            NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...
# 4760         NaN      33.404   25.421333         NaN
# 4761         NaN      33.405   25.425625         NaN
# 4762         NaN   33.410714   25.437143         NaN
# 4763         NaN      33.414       25.45         NaN
# 4764         NaN      33.429   25.464333         NaN
#
# [4765 rows x 18 columns]

# %%
# Funcion para limpiar los datos del dataframe de CTD

def limpieza_ctd(df):

    # Eliminamos las filas innecesarias 
    df = df.iloc[10: , :]

    # Realizamos una copia del dataframe
    df_ctd_copy = df.copy()

    #Reiniciamos los indices del dataframe 
    df_ctd_copy = df_ctd_copy.reset_index()

    #Eliminamos la columna de index 
    df_ctd_copy = df_ctd_copy.iloc[: , 1:]

    #Dejamos la primera fila como columna 
    df_ctd_copy.columns = df_ctd_copy.iloc[0]

    #Eliminamos la primera fila del dataframe 
    df_ctd_copy = df_ctd_copy.iloc[2: , :]

    # Reiniciamos los index
    df_ctd_copy =  df_ctd_copy.reset_index()

    #Eliminamos la columna index 
    df_ctd_copy =  df_ctd_copy.iloc[: , 1:]

    # Creamos una columna de FECHA en la posicion 9 del dataframe
    df_ctd_copy.insert(10 , 'FECHA' , df_ctd_copy.apply(lambda row: datetime.datetime(row['YEAR'], row['MONTH'], row['DAY']), axis=1) )  

    #Creamos una columna de ID en la posicion 0 
    df_ctd_copy.insert(0 , 'ID' , df_ctd_copy.index + 1 )

    #Formateamos la FECHA  a DD/MM/YYYY 
    # Formatear la fecha y hora al formato deseado
    df_ctd_copy['FECHA'] = df_ctd_copy['FECHA'].dt.strftime('%d/%m/%Y %H:%M:%S')

    #Renombramos las columnas de variables
    df_ctd_copy = df_ctd_copy.rename(columns= { 'STATION' : 'ESTACION'  , 'CRUISE'  : 'SEGUIMIENTO' , 'LATITUDE' : 'LATITUD' , 'LONGITUDE' : 'LONGITUD'  ,  'TEMPERATURE_(°C)' : 'TEMPERATURA °C' ,  'OXIGENO_DIS_(ML/L)' : 'OXIGENO_DIS_ML/L ML/L' , 'OXIGENO_DIS_(MG/L)' : 'OXIGENO_DIS_MG/L MG/L' , 'OXIGENO_DIS_(%SAT)' : 'OXIGENO_DIS_SAT %' , 'OXIGENO_DIS_(UMOL/KG)' : 'OXIGENO_DIS_UMOLKG UMOL/KG' , 'SALINITY_(PSU)' : 'SALINIDAD PSU' , 'DENSIDAD_(KG/M3)' : 'DENSIDAD KG/M3' , 'FLUORESCENCIA_(MG/M-3)' : 'FLUORESCENCIA MG/M-3' , 'DEPHT_(M)' : 'PROFUNDIDAD'})

    #Creamos una lista con las columnas del dataframe
    columnas = df_ctd_copy.columns.tolist()

    #Obtenemos las columnas fijas y las columnas Variables 
    columnas_fijas = columnas[:12]
    columnas_variables = columnas[12:]
    
    #Realizamos un melt para convertir las columnas de Variables a Filas 

    # Dataframe 
    # id_vars : columnas_fijas
    # value_vars : columnas_variables
    # var_name : Nombre de la nueva columna 
    # value_name : Nombre de la nueva columna de valores 

    df_ctd_copy  = pd.melt(df_ctd_copy , id_vars= columnas_fijas , var_name= 'VARIABLE' , value_vars= columnas_variables , value_name= 'VALOR' )

    #Volvemos a crear una lista con las columnas del dataframe
    columnas = df_ctd_copy.columns.tolist()

    #Creamos una columna llamada Unidad obteniendo lo que viene despues del espacio en la columna VARIABLE
    df_ctd_copy.insert(12 , 'UNIDAD' , df_ctd_copy['VARIABLE'].str.split(' ', n=1).str[1])

    #Luego eliminamos las Unidades de la columna Variable 
    df_ctd_copy['VARIABLE'] =  df_ctd_copy['VARIABLE'].str.split(' ' , n=1).str[0]

    #Dejamos todas las estaciones en MAYUSCULA
    df_ctd_copy['ESTACION'] =  df_ctd_copy['ESTACION'].str.upper()

    # Creamos un diccionario de mapeo de sectores
    mapeo_sectores = {
            
            "TEN" :  "Tenaun" ,
            "CHAU" : "Chaulinec" ,
            "CHIC" : "Chiloe central" ,
            "CHAC" : "Chacao" ,
            "QUELL" : "Quellon",
            "BUT" : "Butachauques",
            "ANC" : "Ancud" ,
            "REL" : "Reloncavi" ,
            "CALB" : "Calbuco"

    }

    #Creamos un diccionario de mapeo de regiones
    mapeo_regiones = {'Estuario' : 'X' , 'Reloncavi' : 'X' , 'Calbuco' : 'X' , 'Maullin' : 'X' , 'Ancud' : 'X' , 'Chacao' : 'X' , 'Butachauques' : 'X' , 'Chaulinec' : 'X' , 'Tenaun' : 'X' , 'Chiloe central'  : 'X' ,
                  'Desertores' : 'X' , 'Quellon' : 'X' ,  'Hornopiren' : 'X' , 'Ayacara' : 'X' , 'Chaiten' : 'X' ,  'Guaitecas' : 'XI' , 'Moraleda' : 'XI' , 'Puyuhuapi' : 'XI' , 'Aysen' : 'XI' , 'Coquimbo' : 'IV' , 'Atacama' : 'III' , 'Pto. Natales' : 'XII' , 'Bio-Bio' : 'VIII' }

    # Extraemos los Números de la columna ESTACION para crear una la columna N_ESTACION
    df_ctd_copy['N_ESTACION'] = df_ctd_copy['ESTACION'].str.extract(r'(\d+)')

    #Obtenemos el código utilizando la expresion regular 
    df_ctd_copy['CODIGO_EXTRAIDO'] = df_ctd_copy['ESTACION'].str.extract(r'([A-Z]{3,5})')

    #Luego utilizando el diccionario de mapeo creamos la columna de SECTOR utilizando la funcion map

    df_ctd_copy['SECTOR'] = df_ctd_copy['CODIGO_EXTRAIDO'].map(mapeo_sectores)

    #Utilizando el diccionario de mapeo de regiones creamos la columna de COD_REGION utilizando la funcion map

    df_ctd_copy['COD_REGION'] = df_ctd_copy['SECTOR'].map(mapeo_regiones)


    return df_ctd_copy , columnas , columnas_fijas , columnas_variables

# %%
df_ctd_copy , columnas , columnas_fijas , columnas_variables  = limpieza_ctd(df_ctd)

# %%
df_ctd_copy.columns
# Out:
# Index(['ID', 'NOMB_PROY', 'INST_PROY', 'SEGUIMIENTO', 'ESTACION', 'LONGITUD',
#        'LATITUD', 'DAY', 'MONTH', 'YEAR', 'PROFUNDIDAD', 'FECHA', 'UNIDAD',
#        'VARIABLE', 'VALOR', 'N_ESTACION', 'CODIGO_EXTRAIDO', 'SECTOR',
#        'COD_REGION'],
#       dtype='object')

# %%
df_ctd_copy['COD_REGION'].unique()
# Out:
# array(['X'], dtype=object)

# %%
df_ctd_copy.to_csv("output/2014/AMBIENTALES_CTD_2014.csv" , index=False)

# %% [markdown]
# # Limpieza de los datos de fisio quimicos 2014

# %%
df_fisio = pd.read_excel(r"C:\Users\Felipe Abarzúa\Desktop\DATA_AMBIENTALES\Proyecto Seguimiento Ambiental\2014_P656\1_BD_FISICOQUIMICO_INV-VER 2014.xlsx" , sheet_name="Base de datos2014")

# %%
df_fisio
# Out:
#                                   Nombre del Proyecto:  \
# 0                                      Etapa Proyecto:
# 1                                        Jefe Proyecto
# 2                                        Institucion:
# 3                                      Nombre Sector:
# 4                                              Región:
# ..                                                 ...
# 491  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
# 492  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
# 493  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
# 494  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
# 495  ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULT...
#
#     ESTUDIO DEL DESEMPEÑO AMBIENTAL DE LA ACUICULTURA EN CHILE Y SU EFECTO EN LOS ECOSISTEMAS DE EMPLAZAMIENTO, 2014-2015.  \
# 0    Objetivo 1. Actividad 2. Muestreos y Analisis ...
# 1                                         Gastón Vidal
# 2                        INSTITUTO DE FOMENTO PESQUERO
# 3    Atacama (Caldera-Bahia Inglesa), Coquimbo (Ton...
# 4    Región de Atacama, Región de Coquimbo, Región ...
# ..                                                 ...
# 491  Objetivo 1. Actividad 2. Muestreos y Analisis ...
# 492  Objetivo 1. Actividad 2. Muestreos y Analisis ...
# 493  Objetivo 1. Actividad 2. Muestreos y Analisis ...
# 494  Objetivo 1. Actividad 2. Muestreos y Analisis ...
# 495  Objetivo 1. Actividad 2. Muestreos y Analisis ...
#
#        Unnamed: 2                     Unnamed: 3  \
# 0             NaN                            NaN
# 1             NaN                            NaN
# 2             NaN                            NaN
# 3             NaN                            NaN
# 4             NaN                            NaN
# ..            ...                            ...
# 491  Gastón Vidal  INSTITUTO DE FOMENTO PESQUERO
# 492  Gastón Vidal  INSTITUTO DE FOMENTO PESQUERO
# 493  Gastón Vidal  INSTITUTO DE FOMENTO PESQUERO
# 494  Gastón Vidal  INSTITUTO DE FOMENTO PESQUERO
# 495  Gastón Vidal  INSTITUTO DE FOMENTO PESQUERO
#
#                                          Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                                               NaN        NaN        NaN
# 1                                               NaN        NaN        NaN
# 2                                               NaN        NaN        NaN
# 3                                               NaN        NaN        NaN
# 4                                               NaN        NaN        NaN
# ..                                              ...        ...        ...
# 491  Campaña_Inv_Ver_2014.Proy.SeguimientoAmbiental    Bio-Bio         16
# 492  Campaña_Inv_Ver_2014.Proy.SeguimientoAmbiental    Bio-Bio         17
# 493  Campaña_Inv_Ver_2014.Proy.SeguimientoAmbiental    Bio-Bio         18
# 494  Campaña_Inv_Ver_2014.Proy.SeguimientoAmbiental    Bio-Bio         19
# 495  Campaña_Inv_Ver_2014.Proy.SeguimientoAmbiental    Bio-Bio         20
#
#        Unnamed: 7    Unnamed: 8    Unnamed: 9  ... Unnamed: 30 Unnamed: 31  \
# 0             NaN           NaN           NaN  ...         NaN         NaN
# 1             NaN           NaN           NaN  ...         NaN         NaN
# 2             NaN           NaN           NaN  ...         NaN         NaN
# 3             NaN           NaN           NaN  ...         NaN         NaN
# 4             NaN           NaN           NaN  ...         NaN         NaN
# ..            ...           ...           ...  ...         ...         ...
# 491  37°04'07,8''  73°09'35,7''  37°04'07,8''  ...   64.919362    5.295842
# 492  37°04'13,3''  73°09'15,0''  37°04'13,3''  ...   97.982042    1.399441
# 493  37°03'31,2''  73°08'52,0''  37°03'31,2''  ...   88.200455    8.321741
# 494  37°03'11,1''  73°08'53,9''  37°03'11,1''  ...   92.526524   14.405984
# 495  37°02'54,6''  73°09'21,5''  37°02'54,6''  ...   55.332802    73.38742
#
#     Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37  \
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...         ...
# 491    1.917609    0.134615    33.16303    2.944296    0.101144    0.736305
# 492     1.89731    0.061944    0.120648    2.754201    2.929209    0.712194
# 493     11.3468    0.771562    0.452746    3.274291    3.300836    0.769742
# 494    7.326558    0.448108    0.146918    2.998681    2.415448    1.070738
# 495   42.641436    1.543712    2.025761    3.913315    2.867916    1.211622
#
#     Unnamed: 38 Unnamed: 39
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# ..          ...         ...
# 491    1.484714     Bio-Bio
# 492    0.683727     Bio-Bio
# 493    0.743382     Bio-Bio
# 494    0.995062     Bio-Bio
# 495    1.690625     Bio-Bio
#
# [496 rows x 40 columns]

# %%
df_fisio_copy = df_fisio.copy()
 
#Eliminamos las filas innecesarias
df_fisio_copy =  df_fisio_copy.iloc[14: , :]

# Reiniciamos los index
df_fisio_copy = df_fisio_copy.reset_index(drop= True)

#Dejamos la primera fila como columna 
df_fisio_copy.columns = df_fisio_copy.iloc[0]

# Creamos una lista de las columnas
columnas = df_fisio_copy.columns.tolist()

#Eliminamos la primera fila del dataset
df_fisio_copy = df_fisio_copy.iloc[1: , :]

# Reiniciamos los index
df_fisio_copy =  df_fisio_copy.reset_index(drop= True)

# Eliminamos las columnas innecesarias

df_fisio_copy = df_fisio_copy.iloc[:, 
    list(range(0, 4)) +        # 0 a 3
    list(range(5, 12)) +       # 5 a 11
    [13, 15, 17, 19, 21, 23, 25, 27] +  # índices sueltos
    list(range(28, 39))        # 28 a 39
]

# Realizamos una lista de las columnas 

lista_columnas = df_fisio_copy.columns.tolist()




# Realizamos un ciclo para poder modificar las columnas del dataframe

for indice, columna in enumerate(lista_columnas):
    if 10 <= indice < 30:
        if indice % 2 == 0:
            # Par: agregar INV al nombre actual
            lista_columnas[indice] = f"{columna} INV"
        else:
            # Impar: tomar la anterior y quitar ' INV' si lo tiene
            prev = lista_columnas[indice - 1]
            if isinstance(prev, str) and prev.endswith(' INV'):
                prev_base = prev[:-4]
            else:
                prev_base = prev
            lista_columnas[indice] = f"{prev_base} VER"



# Creamos una funcion para eliminar todo el contenido que son (*)

def es_nan(x):
    return isinstance(x, float) and math.isnan(x)


def quitar_parentesis_contenido(lista):
 
    resultado = []
    patron = re.compile(r'\([^)]*\)')  # todo lo que esté entre paréntesis (no anida)
    for c in lista:
        if es_nan(c) or c is None:
            resultado.append(c)
        elif isinstance(c, str):
            s = patron.sub('', c)                 # quita ( ... )
            s = re.sub(r'\s{2,}', ' ', s).strip() # colapsa espacios y recorta
            resultado.append(s)
        else:
            resultado.append(c)
    return resultado


# Utilizamos la funcion para limpiar la lista de columnas 

lista_columnas = quitar_parentesis_contenido(lista_columnas)


# Asignamos la lista de columnas creadas al dataframe 

df_fisio_copy.columns = lista_columnas


# Eliminamos la primera fila 

df_fisio_copy = df_fisio_copy.iloc[1: , 1:]

# Reiniciamos los index
df_fisio_copy =  df_fisio_copy.reset_index(drop= True)

# Crear la columna ID autoincrementable
id_columna = range(1, len(df_fisio_copy) + 1)  # genera 1, 2, 3, ...

# Agregamos una columna de ID 
df_fisio_copy.insert(0 , "ID" , df_fisio_copy.index + 1 )

# Creamos dos dataset uno para INV y VER

df_fisio_copy_inv = df_fisio_copy[['ID', 'ETAP_PROY', 'JEFE_PROY', 'INST_PROY', 'ZONA', 'ESTACION',
       'Latitud S INV' , 'Longitud W INV' , 'pH INV', 'Temperatura INV',
       'Redox EHNHE INV',  'Sulfuros INV', 
       'Materia orgánica total INV', 'Arena INV',
       'Fango INV',  'Grava INV',
       'Tamaño medio INV', 'Selección INV']]


# Creamos la lista de columnas para el dataset inv

lista_columnas_inv = df_fisio_copy_inv.columns.to_list()


df_fisio_copy_ver = df_fisio_copy[['ID', 'ETAP_PROY', 'JEFE_PROY', 'INST_PROY', 'ZONA', 'ESTACION',
      'Latitud S VER', 'Longitud W VER', 'pH VER',  'Temperatura VER',
       'Redox EHNHE VER', 'Sulfuros VER',
       'Materia orgánica total VER', 
       'Arena VER', 'Fango VER',  'Grava VER',
        'Tamaño medio VER', 'Selección VER']]

# Creamos la lista de columnas para el dataset ver 

lista_columnas_ver = df_fisio_copy_ver.columns.to_list()

#  Realizar un melt a cada dataset para convertir las columnas en filas 

def convertir_columnas_dataframe(df , lista_columnas):
 
  # Obtenemos las columnas fijas y variables
    columnas_fijas = [lista_columnas[i] for i in range(0, 8)]      # posiciones 0 a 8
    columnas_variables = [lista_columnas[i] for i in range(8, 18)] # posiciones 8 a 17

   # Realizamos un melt para convertir las columnas variables en filas

    df = df.melt( id_vars = columnas_fijas , var_name = "VARIABLE"  , value_vars = columnas_variables , value_name = 'VALOR')

    return df , columnas_fijas , columnas_variables

# Realizamos el melt de INV y VER para convertir las columnas de variables en filas
df_fisio_inv_melt , columnas_fijas_inv , columnas_variables_inv = convertir_columnas_dataframe(df_fisio_copy_inv , lista_columnas_inv)
df_fisio_ver_melt , columnas_fijas_ver , columnas_variables_ver = convertir_columnas_dataframe(df_fisio_copy_ver , lista_columnas_ver)

# Reemplazamos los valores de sd de la columna VALOR por nulo 

df_fisio_ver_melt['VALOR'] = np.where(df_fisio_ver_melt["VALOR"] == "sd" , np.nan , df_fisio_ver_melt['VALOR'] )
df_fisio_inv_melt['VALOR'] = np.where(df_fisio_inv_melt["VALOR"] == "sd" , np.nan , df_fisio_inv_melt['VALOR'] )

# Creamos una columna llamada ESTACION_DEL_ANIO para diferenciar INV Y VER

df_fisio_ver_melt['ESTACION_DEL_ANIO'] = "VER" 
df_fisio_inv_melt['ESTACION_DEL_ANIO'] = "INV"


# Creamos una funcion para eliminar los grados , minutos y segundos con regex

# Aplicamos la funcion a la latitud y longitud  a los dataframes

df_fisio_ver_melt['Longitud W VER'] = df_fisio_ver_melt['Longitud W VER'].str.replace(r"[°'\"]", "", regex=True)
df_fisio_ver_melt['Latitud S VER'] = df_fisio_ver_melt['Latitud S VER'].str.replace(r"[°'\"]", "", regex=True)

df_fisio_inv_melt['Longitud W INV'] = df_fisio_inv_melt['Longitud W INV'].str.replace(r"[°'\"]", "", regex=True)
df_fisio_inv_melt['Latitud S INV'] = df_fisio_inv_melt['Latitud S INV'].str.replace(r"[°'\"]", "", regex=True)

# Borrar INV y VER de los campos LATITUD Y LONGITUD y VARIABLE

df_fisio_inv_melt = df_fisio_inv_melt.rename(columns={'Latitud S INV' : 'LATITUD' , 'Longitud W INV' : 'LONGITUD'})

df_fisio_ver_melt =  df_fisio_ver_melt.rename(columns={'Latitud S VER' : 'LATITUD' , 'Longitud W VER' : 'LONGITUD' })

# Ahora borramos INV y VER de las VARIABLES

df_fisio_inv_melt['VARIABLE'] = df_fisio_inv_melt['VARIABLE'].str.replace('INV' , '')

df_fisio_ver_melt['VARIABLE'] = df_fisio_ver_melt['VARIABLE'].str.replace('VER' , '')

# Luego aplicamos un rstrip para eliminar los espacios en blanco al final del texto

df_fisio_inv_melt['VARIABLE'] = df_fisio_inv_melt['VARIABLE'].str.rstrip()
df_fisio_ver_melt['VARIABLE'] = df_fisio_ver_melt['VARIABLE'].str.rstrip()

# Ahora aplicamos un upper para dejar todo en mayúscula
df_fisio_inv_melt['VARIABLE'] = df_fisio_inv_melt['VARIABLE'].str.upper()
df_fisio_ver_melt['VARIABLE'] = df_fisio_ver_melt['VARIABLE'].str.upper()

# Ahora habia que realizar un concat para unir los dataframes 
df_fisio_2014 = pd.concat([df_fisio_inv_melt , df_fisio_ver_melt])

# Agregamos el año
df_fisio_2014['ANIO'] = 2014

# %%
df_fisio_2014.query("ID == 1")
# Out:
#       ID                                          ETAP_PROY     JEFE_PROY  \
# 0      1  Objetivo 1. Actividad 2. Muestreos y Analisis ...  Gastón Vidal
# 480    1  Objetivo 1. Actividad 2. Muestreos y Analisis ...  Gastón Vidal
# 960    1  Objetivo 1. Actividad 2. Muestreos y Analisis ...  Gastón Vidal
# 1440   1  Objetivo 1. Actividad 2. Muestreos y Analisis ...  Gastón Vidal
# 1920   1  Objetivo 1. Actividad 2. Muestreos y Analisis ...  Gastón Vidal
# 2400   1  Objetivo 1. Actividad 2. Muestreos y Analisis ...  Gastón Vidal
# 2880   1  Objetivo 1. Actividad 2. Muestreos y Analisis ...  Gastón Vidal
# 3360   1  Objetivo 1. Actividad 2. Muestreos y Analisis ...  Gastón Vidal
# 3840   1  Objetivo 1. Actividad 2. Muestreos y Analisis ...  Gastón Vidal
# 4320   1  Objetivo 1. Actividad 2. Muestreos y Analisis ...  Gastón Vidal
# 0      1  Objetivo 1. Actividad 2. Muestreos y Analisis ...  Gastón Vidal
# 480    1  Objetivo 1. Actividad 2. Muestreos y Analisis ...  Gastón Vidal
# 960    1  Objetivo 1. Actividad 2. Muestreos y Analisis ...  Gastón Vidal
# 1440   1  Objetivo 1. Actividad 2. Muestreos y Analisis ...  Gastón Vidal
# 1920   1  Objetivo 1. Actividad 2. Muestreos y Analisis ...  Gastón Vidal
# 2400   1  Objetivo 1. Actividad 2. Muestreos y Analisis ...  Gastón Vidal
# 2880   1  Objetivo 1. Actividad 2. Muestreos y Analisis ...  Gastón Vidal
# 3360   1  Objetivo 1. Actividad 2. Muestreos y Analisis ...  Gastón Vidal
# 3840   1  Objetivo 1. Actividad 2. Muestreos y Analisis ...  Gastón Vidal
# 4320   1  Objetivo 1. Actividad 2. Muestreos y Analisis ...  Gastón Vidal
#
#                           INST_PROY      ZONA ESTACION   LATITUD  LONGITUD  \
# 0     INSTITUTO DE FOMENTO PESQUERO  Estuario        1  412614,9  721747,9
# 480   INSTITUTO DE FOMENTO PESQUERO  Estuario        1  412614,9  721747,9
# 960   INSTITUTO DE FOMENTO PESQUERO  Estuario        1  412614,9  721747,9
# 1440  INSTITUTO DE FOMENTO PESQUERO  Estuario        1  412614,9  721747,9
# 1920  INSTITUTO DE FOMENTO PESQUERO  Estuario        1  412614,9  721747,9
# 2400  INSTITUTO DE FOMENTO PESQUERO  Estuario        1  412614,9  721747,9
# 2880  INSTITUTO DE FOMENTO PESQUERO  Estuario        1  412614,9  721747,9
# 3360  INSTITUTO DE FOMENTO PESQUERO  Estuario        1  412614,9  721747,9
# 3840  INSTITUTO DE FOMENTO PESQUERO  Estuario        1  412614,9  721747,9
# 4320  INSTITUTO DE FOMENTO PESQUERO  Estuario        1  412614,9  721747,9
# 0     INSTITUTO DE FOMENTO PESQUERO  Estuario        1  412441,5  721707,0
# 480   INSTITUTO DE FOMENTO PESQUERO  Estuario        1  412441,5  721707,0
# 960   INSTITUTO DE FOMENTO PESQUERO  Estuario        1  412441,5  721707,0
# 1440  INSTITUTO DE FOMENTO PESQUERO  Estuario        1  412441,5  721707,0
# 1920  INSTITUTO DE FOMENTO PESQUERO  Estuario        1  412441,5  721707,0
# 2400  INSTITUTO DE FOMENTO PESQUERO  Estuario        1  412441,5  721707,0
# 2880  INSTITUTO DE FOMENTO PESQUERO  Estuario        1  412441,5  721707,0
# 3360  INSTITUTO DE FOMENTO PESQUERO  Estuario        1  412441,5  721707,0
# 3840  INSTITUTO DE FOMENTO PESQUERO  Estuario        1  412441,5  721707,0
# 4320  INSTITUTO DE FOMENTO PESQUERO  Estuario        1  412441,5  721707,0
#
#                     VARIABLE       VALOR ESTACION_DEL_ANIO  ANIO
# 0                         PH        7.18               INV  2014
# 480              TEMPERATURA   11.333333               INV  2014
# 960              REDOX EHNHE   88.366667               INV  2014
# 1440                SULFUROS   36.338871               INV  2014
# 1920  MATERIA ORGÁNICA TOTAL    6.310707               INV  2014
# 2400                   ARENA   73.787199               INV  2014
# 2880                   FANGO   22.231523               INV  2014
# 3360                   GRAVA    3.981278               INV  2014
# 3840            TAMAÑO MEDIO    2.294185               INV  2014
# 4320               SELECCIÓN    1.632729               INV  2014
# 0                         PH    7.366667               VER  2014
# 480              TEMPERATURA        12.8               VER  2014
# 960              REDOX EHNHE        77.2               VER  2014
# 1440                SULFUROS  149.041979               VER  2014
# 1920  MATERIA ORGÁNICA TOTAL    5.005702               VER  2014
# 2400                   ARENA    10.66305               VER  2014
# 2880                   FANGO    89.33695               VER  2014
# 3360                   GRAVA           0               VER  2014
# 3840            TAMAÑO MEDIO    4.348927               VER  2014
# 4320               SELECCIÓN    0.508709               VER  2014
